# %% [markdown]
# Official github: [StasBomb](https://github.com/statsbomb/statsbombpy)

# %% [markdown]
# # Step 0: Install the needed libraries

# %%
import subprocess
import sys

# List of required packages
required_packages = [
    "pandas", "numpy", "matplotlib", "seaborn", "networkx"
]

def install_package(package):
    """Installs a package using pip if it's not already installed."""
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Check and install missing packages
for package in required_packages:
    install_package(package)
# Out:
# pandas is already installed.
# numpy is already installed.
# matplotlib is already installed.
# seaborn is already installed.
# networkx is already installed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import random

from matplotlib.patches import Arc

# %% [markdown]
# # Step 1: Install StasBomb Data Library

# %% [markdown]
# StatsBomb provides a rich, event-based dataset for football analytics. It includes detailed match event data such as passes, shots, tackles, dribbles, defensive actions, and pressures, with precise spatio-temporal information (x, y coordinates). The
# key Features of StatsBomb Data Library are:
#
#  - Pass Data → Pass origin, destination, type, and success/failure.
#  - Shot Data → Shot location, expected goals (xG), outcome (goal, miss, block).
#  - Defensive Actions → Tackles, interceptions, pressing intensity.
#  - Possession & Transition Data → Who has the ball, where, and under what conditions.
#
# The dataset covers multiple leagues and competitions, including:
#
#  - La Liga
#  - Premier League
#  - World Cup
#  - UEFA Champions League
#
# By using StatsBomb Open Data, we can analyze team formations, player tendencies, and tactical setups in a data-driven way.

# %%
install_package("statsbombpy")
# Out:
# statsbombpy is already installed.

# %%
from statsbombpy import sb

# %% [markdown]
# # Step 2: Load Available Competitions from StatsBomb

# %%
# Suppress the authentication warning
import warnings
from statsbombpy.api_client import NoAuthWarning
warnings.simplefilter("ignore", NoAuthWarning)

# %% [markdown]
# Let's retrieve all available competitions from the library, orders them by season (from oldest to latest) and diplays them

# %%
# Load competitions
competitions = sb.competitions()

# Convert 'season_name' to integer for proper sorting
competitions['season_year'] = competitions['season_name'].str[:4].astype(int)

# Order by season (oldest first)
competitions = competitions.sort_values(by='season_year', ascending=True)

# Count competitions per year
competition_counts = competitions['season_year'].value_counts().sort_index(ascending=False)

# Display competitions in an ordered format
print("Available Competitions in StatsBomb Open Data (Ordered by Year):\n")
for _, row in competitions.iterrows():
    print(f"{row['season_name']} | {row['competition_name']} ({row['competition_gender'].capitalize()})")

# Show the sorted DataFrame for reference
display(competitions)
# Out:
# Available Competitions in StatsBomb Open Data (Ordered by Year):
#
# 1958 | FIFA World Cup (Male)
# 1962 | FIFA World Cup (Male)
# 1970 | FIFA World Cup (Male)
# 1970/1971 | Champions League (Male)
# 1971/1972 | Champions League (Male)
# 1972/1973 | Champions League (Male)
# 1973/1974 | La Liga (Male)
# 1974 | FIFA World Cup (Male)
# 1977 | North American League (Male)
# 1977/1978 | Copa del Rey (Male)
# 1979 | FIFA U20 World Cup (Male)
# 1981 | Liga Profesional (Male)
# 1982/1983 | Copa del Rey (Male)
# 1983/1984 | Copa del Rey (Male)
# 1986/1987 | Serie A (Male)
# 1986 | FIFA World Cup (Male)
# 1988/1989 | UEFA Europa League (Male)
# 1990 | FIFA World Cup (Male)
# 1997/1998 | Liga Profesional (Male)
# 1999/2000 | Champions League (Male)
# 2003/2004 | Premier League (Male)
# 2003/2004 | Champions League (Male)
# 2004/2005 | Champions League (Male)
# 2004/2005 | La Liga (Male)
# 2005/2006 | La Liga (Male)
# 2006/2007 | Champions League (Male)
# 2006/2007 | La Liga (Male)
# 2007/2008 | La Liga (Male)
# 2008/2009 | Champions League (Male)
# 2008/2009 | La Liga (Male)
# 2009/2010 | La Liga (Male)
# 2009/2010 | Champions League (Male)
# 2010/2011 | La Liga (Male)
# 2010/2011 | Champions League (Male)
# 2011/2012 | Champions League (Male)
# 2011/2012 | La Liga (Male)
# 2012/2013 | Champions League (Male)
# 2012/2013 | La Liga (Male)
# 2013/2014 | La Liga (Male)
# 2013/2014 | Champions League (Male)
# 2014/2015 | Champions League (Male)
# 2014/2015 | La Liga (Male)
# 2015/2016 | 1. Bundesliga (Male)
# 2015/2016 | Ligue 1 (Male)
# 2015/2016 | Premier League (Male)
# 2015/2016 | Champions League (Male)
# 2015/2016 | La Liga (Male)
# 2015/2016 | Serie A (Male)
# 2016/2017 | La Liga (Male)
# 2016/2017 | Champions League (Male)
# 2017/2018 | Champions League (Male)
# 2017/2018 | La Liga (Male)
# 2018/2019 | La Liga (Male)
# 2018 | NWSL (Female)
# 2018 | FIFA World Cup (Male)
# 2018/2019 | FA Women's Super League (Female)
# 2018/2019 | Champions League (Male)
# 2019 | Women's World Cup (Female)
# 2019/2020 | FA Women's Super League (Female)
# 2019/2020 | La Liga (Male)
# 2020/2021 | La Liga (Male)
# 2020/2021 | FA Women's Super League (Female)
# 2020 | UEFA Euro (Male)
# 2021/2022 | Ligue 1 (Male)
# 2021/2022 | Indian Super league (Male)
# 2022/2023 | Ligue 1 (Male)
# 2022 | FIFA World Cup (Male)
# 2022 | UEFA Women's Euro (Female)
# 2023 | Major League Soccer (Male)
# 2023 | Women's World Cup (Female)
# 2023 | African Cup of Nations (Male)
# 2023/2024 | 1. Bundesliga (Male)
# 2024 | Copa America (Male)
# 2024 | UEFA Euro (Male)
#     competition_id  season_id   country_name        competition_name
# 36              43        269  International          FIFA World Cup  \
# 35              43        270  International          FIFA World Cup
# 34              43        272  International          FIFA World Cup
# 20              16        276         Europe        Champions League
# 19              16         71         Europe        Champions League
# ..             ...        ...            ...                     ...
# 72              72        107  International       Women's World Cup
# 2             1267        107         Africa  African Cup of Nations
# 0                9        281        Germany           1. Bundesliga
# 21             223        282  South America            Copa America
# 68              55        282         Europe               UEFA Euro
#
#    competition_gender  competition_youth  competition_international
# 36               male              False                       True  \
# 35               male              False                       True
# 34               male              False                       True
# 20               male              False                      False
# 19               male              False                      False
# ..                ...                ...                        ...
# 72             female              False                       True
# 2                male              False                       True
# 0                male              False                      False
# 21               male              False                       True
# 68               male              False                       True
#
#    season_name               match_updated           match_updated_360
# 36        1958  2024-02-13T14:22:08.222297                        None  \
# 35        1962  2023-06-26T10:38:00.323984                        None
# 34        1970  2024-02-13T14:23:06.735299                        None
# 20   1970/1971  2024-02-13T14:24:12.213582                        None
# 19   1971/1972  2024-02-12T14:25:01.735880     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 72        2023  2024-07-14T16:59:48.469596  2024-07-14T17:01:38.887279
# 2         2023  2024-06-13T07:51:02.452825                        None
# 0    2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 21        2024  2024-07-15T18:00:33.653673                        None
# 68        2024  2024-07-15T15:48:50.315500  2024-07-15T15:52:24.778809
#
#            match_available_360             match_available  season_year
# 36                        None  2024-02-13T14:22:08.222297         1958
# 35                        None  2023-06-26T10:38:00.323984         1962
# 34                        None  2024-02-13T14:23:06.735299         1970
# 20                        None  2024-02-13T14:24:12.213582         1970
# 19                        None  2024-02-12T14:25:01.735880         1971
# ..                         ...                         ...          ...
# 72  2024-07-14T17:01:38.887279  2024-07-14T16:59:48.469596         2023
# 2                         None  2024-06-13T07:51:02.452825         2023
# 0   2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676         2023
# 21                        None  2024-07-15T18:00:33.653673         2024
# 68  2024-07-15T15:52:24.778809  2024-07-15T15:48:50.315500         2024
#
# [74 rows x 13 columns]

# %% [markdown]
# ## Step 2.1: Print all the Matches in the Dataset

# %% [markdown]
# Let's print all the matches contained in the dataset in chronological order

# %%
# Load all competitions
comps = sb.competitions()

# Extract the numeric year from 'season_name' (e.g. "2023/2024" -> 2023)
comps['season_year'] = comps['season_name'].str[:4].astype(int)

# Sort competition ascending by'season_year'
comps_sorted = comps.sort_values(by='season_year', ascending=True).reset_index(drop=True)

all_matches_list = []
total_matches = 0

# Iterate over competitions in chronological order
for idx, row in comps_sorted.iterrows():
    cid = row['competition_id']
    sid = row['season_id']
    comp_name = row['competition_name']
    season_name = row['season_name']
    season_year = row['season_year']
    
    # Load matches for the competition + season
    comp_matches = sb.matches(competition_id=cid, season_id=sid)
    
    # Sort by match_date ascending
    comp_matches = comp_matches.sort_values(by='match_date', ascending=True)
    
    # Print matches in chronological order
    print(40*"=")
    print(f"{season_year} | {comp_name} ({season_name})\n")
    match_count = 0
    for m_idx, m_row in comp_matches.iterrows():
        match_date = m_row['match_date']
        home_team  = m_row['home_team']
        away_team  = m_row['away_team']
        home_score = m_row['home_score']
        away_score = m_row['away_score']
        
        # Print each match line: date, home vs away, final score
        print(f"{match_date} | {home_team} - {away_team} {home_score}:{away_score}")
        match_count += 1

    # Print the total number of matches for this competition + season
    print(f"\nTotal matches for this competition: {match_count}")
    
    # Accumulate into an overall total and list
    total_matches += match_count
    all_matches_list.append(comp_matches)

# This will create a single DataFrame with all matches
all_matches = pd.concat(all_matches_list, ignore_index=True)

# Print the grand total of matches across all competitions/seasons
print("\n-------------------------------------------")
print(f"Grand total across all comps/seasons: {total_matches} matches")
# Out:
# ========================================
# 1958 | FIFA World Cup (1958)
#
# 1958-06-24 | Brazil - France 5:2
# 1958-06-29 | Brazil - Sweden 5:2
#
# Total matches for this competition: 2
# ========================================
# 1962 | FIFA World Cup (1962)
#
# 1962-05-30 | Brazil - Mexico 2:0
#
# Total matches for this competition: 1
# ========================================
# 1970 | FIFA World Cup (1970)
#
# 1970-06-04 | Brazil - Czechoslovakia 4:1
# 1970-06-07 | Brazil - England 1:0
# 1970-06-10 | Brazil - Romania 3:2
# 1970-06-14 | Brazil - Peru 4:2
# 1970-06-18 | Brazil - Uruguay 3:1
# 1970-06-21 | Brazil - Italy 4:1
#
# Total matches for this competition: 6
# ========================================
# 1970 | Champions League (1970/1971)
#
# 1971-06-02 | Ajax - Panathinaikos 2:0
#
# Total matches for this competition: 1
# ========================================
# 1971 | Champions League (1971/1972)
#
# 1972-05-31 | Ajax - Inter Milan 2:0
#
# Total matches for this competition: 1
# ========================================
# 1972 | Champions League (1972/1973)
#
# 1973-05-30 | Ajax - Juventus 1:0
#
# Total matches for this competition: 1
# ========================================
# 1973 | La Liga (1973/1974)
#
# 1974-02-17 | Real Madrid - Barcelona 0:5
#
# Total matches for this competition: 1
# ========================================
# 1974 | FIFA World Cup (1974)
#
# 1974-06-19 | Netherlands - Sweden 0:0
# 1974-06-22 | German DR - Germany 1:0
# 1974-06-26 | Netherlands - Argentina 4:0
# 1974-06-30 | German DR - Netherlands 0:2
# 1974-07-03 | Netherlands - Brazil 2:0
# 1974-07-07 | Netherlands - Germany 1:2
#
# Total matches for this competition: 6
# ========================================
# 1977 | North American League (1977)
#
# 1977-08-28 | NY Cosmos - Seattle Sounders 2:1
#
# Total matches for this competition: 1
# ========================================
# 1977 | Copa del Rey (1977/1978)
#
# 1978-04-19 | Barcelona - Las Palmas 3:1
#
# Total matches for this competition: 1
# ========================================
# 1979 | FIFA U20 World Cup (1979)
#
# 1979-09-07 | Argentina U20 - Soviet Union U20 3:1
#
# Total matches for this competition: 1
# ========================================
# 1981 | Liga Profesional (1981)
#
# 1981-04-10 | Boca Juniors - River Plate 3:0
#
# Total matches for this competition: 1
# ========================================
# 1982 | Copa del Rey (1982/1983)
#
# 1983-06-04 | Barcelona - Real Madrid 2:1
#
# Total matches for this competition: 1
# ========================================
# 1983 | Copa del Rey (1983/1984)
#
# 1984-05-05 | Athletic Club - Barcelona 1:0
#
# Total matches for this competition: 1
# ========================================
# 1986 | Serie A (1986/1987)
#
# 1986-11-09 | Juventus - Napoli 1:3
#
# Total matches for this competition: 1
# ========================================
# 1986 | FIFA World Cup (1986)
#
# 1986-06-22 | Argentina - England 2:1
# 1986-06-26 | Argentina - Belgium 2:0
# 1986-06-29 | Argentina - Germany 3:2
#
# Total matches for this competition: 3
# ========================================
# 1988 | UEFA Europa League (1988/1989)
#
# 1989-03-15 | Napoli - Juventus 3:0
# 1989-04-05 | Napoli - Bayern Munich 2:0
# 1989-05-03 | Napoli - VfB Stuttgart 2:1
#
# Total matches for this competition: 3
# ========================================
# 1990 | FIFA World Cup (1990)
#
# 1990-06-24 | Brazil - Argentina 0:1
#
# Total matches for this competition: 1
# ========================================
# 1997 | Liga Profesional (1997/1998)
#
# 1997-10-25 | River Plate - Boca Juniors 1:2
#
# Total matches for this competition: 1
# ========================================
# 1999 | Champions League (1999/2000)
#
# 1999-11-23 | Fiorentina - Manchester United 2:0
#
# Total matches for this competition: 1
# ========================================
# 2003 | Premier League (2003/2004)
#
# 2003-08-16 | Arsenal - Everton 2:1
# 2003-08-24 | Middlesbrough - Arsenal 0:4
# 2003-08-27 | Arsenal - Aston Villa 2:0
# 2003-08-31 | Manchester City - Arsenal 1:2
# 2003-09-13 | Arsenal - Portsmouth 1:1
# 2003-09-21 | Manchester United - Arsenal 0:0
# 2003-09-26 | Arsenal - Newcastle United 3:2
# 2003-10-04 | Liverpool - Arsenal 1:2
# 2003-10-18 | Arsenal - Chelsea 2:1
# 2003-10-26 | Charlton Athletic - Arsenal 1:1
# 2003-11-01 | Leeds United - Arsenal 1:4
# 2003-11-08 | Arsenal - Tottenham Hotspur 2:1
# 2003-11-22 | Birmingham City - Arsenal 0:3
# 2003-11-30 | Arsenal - Fulham 0:0
# 2003-12-06 | Leicester City - Arsenal 1:1
# 2003-12-14 | Arsenal - Blackburn Rovers 1:0
# 2003-12-20 | Bolton Wanderers - Arsenal 1:1
# 2003-12-26 | Arsenal - Wolverhampton Wanderers 3:0
# 2003-12-29 | Southampton - Arsenal 0:1
# 2004-01-07 | Everton - Arsenal 1:1
# 2004-01-10 | Arsenal - Middlesbrough 4:1
# 2004-01-18 | Aston Villa - Arsenal 0:2
# 2004-02-01 | Arsenal - Manchester City 2:1
# 2004-02-07 | Wolverhampton Wanderers - Arsenal 1:3
# 2004-02-10 | Arsenal - Southampton 2:0
# 2004-02-21 | Chelsea - Arsenal 1:2
# 2004-02-28 | Arsenal - Charlton Athletic 2:1
# 2004-03-13 | Blackburn Rovers - Arsenal 0:2
# 2004-03-20 | Arsenal - Bolton Wanderers 2:1
# 2004-03-28 | Arsenal - Manchester United 1:1
# 2004-04-09 | Arsenal - Liverpool 4:2
# 2004-04-11 | Newcastle United - Arsenal 0:0
# 2004-04-16 | Arsenal - Leeds United 5:0
# 2004-04-25 | Tottenham Hotspur - Arsenal 2:2
# 2004-05-01 | Arsenal - Birmingham City 0:0
# 2004-05-04 | Portsmouth - Arsenal 1:1
# 2004-05-09 | Fulham - Arsenal 0:1
# 2004-05-15 | Arsenal - Leicester City 2:1
#
# Total matches for this competition: 38
# ========================================
# 2003 | Champions League (2003/2004)
#
# 2004-05-26 | AS Monaco - FC Porto 0:3
#
# Total matches for this competition: 1
# ========================================
# 2004 | Champions League (2004/2005)
#
# 2005-05-25 | AC Milan - Liverpool 3:3
#
# Total matches for this competition: 1
# ========================================
# 2004 | La Liga (2004/2005)
#
# 2004-10-16 | Espanyol - Barcelona 0:1
# 2004-10-24 | Barcelona - Osasuna 3:0
# 2004-12-04 | Barcelona - Málaga 4:0
# 2004-12-11 | Albacete - Barcelona 1:2
# 2004-12-21 | Barcelona - Levante UD 2:1
# 2005-04-17 | Barcelona - Getafe 2:0
# 2005-05-01 | Barcelona - Albacete 2:0
#
# Total matches for this competition: 7
# ========================================
# 2005 | La Liga (2005/2006)
#
# 2005-10-01 | Barcelona - Real Zaragoza 2:2
# 2005-10-22 | Barcelona - Osasuna 3:0
# 2005-10-26 | Barcelona - Málaga 2:0
# 2005-11-06 | Getafe - Barcelona 1:3
# 2005-11-19 | Real Madrid - Barcelona 0:3
# 2005-11-27 | Barcelona - Racing Santander 4:1
# 2005-12-04 | Villarreal - Barcelona 0:2
# 2005-12-11 | Barcelona - Sevilla 2:1
# 2005-12-17 | Cádiz - Barcelona 1:3
# 2005-12-20 | Barcelona - Celta Vigo 2:0
# 2006-01-07 | Espanyol - Barcelona 1:2
# 2006-01-15 | Barcelona - Athletic Club 2:1
# 2006-01-22 | Barcelona - Deportivo Alavés 2:0
# 2006-01-29 | Mallorca - Barcelona 0:3
# 2006-02-05 | Barcelona - Atlético Madrid 1:3
# 2006-02-18 | Barcelona - Real Betis 5:1
# 2006-02-25 | Real Zaragoza - Barcelona 0:2
#
# Total matches for this competition: 17
# ========================================
# 2006 | Champions League (2006/2007)
#
# 2007-05-23 | AC Milan - Liverpool 2:1
#
# Total matches for this competition: 1
# ========================================
# 2006 | La Liga (2006/2007)
#
# 2006-08-28 | Celta Vigo - Barcelona 2:3
# 2006-09-09 | Barcelona - Osasuna 3:0
# 2006-09-17 | Racing Santander - Barcelona 0:3
# 2006-09-24 | Barcelona - Valencia 1:1
# 2006-09-30 | Athletic Club - Barcelona 1:3
# 2006-10-15 | Barcelona - Sevilla 3:1
# 2006-10-22 | Real Madrid - Barcelona 2:0
# 2006-11-04 | RC Deportivo La Coruña - Barcelona 1:1
# 2006-11-12 | Barcelona - Real Zaragoza 3:1
# 2007-02-11 | Barcelona - Racing Santander 2:0
# 2007-02-18 | Valencia - Barcelona 2:1
# 2007-02-25 | Barcelona - Athletic Club 3:0
# 2007-03-03 | Sevilla - Barcelona 2:1
# 2007-03-10 | Barcelona - Real Madrid 3:3
# 2007-03-17 | Recreativo Huelva - Barcelona 0:4
# 2007-03-31 | Barcelona - RC Deportivo La Coruña 2:1
# 2007-04-07 | Real Zaragoza - Barcelona 1:0
# 2007-04-15 | Barcelona - Mallorca 1:0
# 2007-04-22 | Villarreal - Barcelona 2:0
# 2007-04-29 | Barcelona - Levante UD 1:0
# 2007-05-05 | Real Sociedad - Barcelona 0:2
# 2007-05-13 | Barcelona - Real Betis 1:1
# 2007-05-20 | Atlético Madrid - Barcelona 0:6
# 2007-05-26 | Barcelona - Getafe 1:0
# 2007-06-09 | Barcelona - Espanyol 2:2
# 2007-06-17 | Gimnàstic Tarragona - Barcelona 1:5
#
# Total matches for this competition: 26
# ========================================
# 2007 | La Liga (2007/2008)
#
# 2007-08-26 | Racing Santander - Barcelona 0:0
# 2007-09-02 | Barcelona - Athletic Club 3:1
# 2007-09-22 | Barcelona - Sevilla 2:1
# 2007-09-26 | Barcelona - Real Zaragoza 4:1
# 2007-09-29 | Levante UD - Barcelona 1:4
# 2007-10-07 | Barcelona - Atlético Madrid 3:0
# 2007-10-20 | Villarreal - Barcelona 3:1
# 2007-10-28 | Barcelona - Almería 2:0
# 2007-11-01 | Real Valladolid - Barcelona 1:1
# 2007-11-04 | Barcelona - Real Betis 3:0
# 2007-11-10 | Getafe - Barcelona 2:0
# 2007-11-24 | Barcelona - Recreativo Huelva 3:0
# 2007-12-01 | Espanyol - Barcelona 1:1
# 2007-12-09 | Barcelona - RC Deportivo La Coruña 2:1
# 2007-12-15 | Valencia - Barcelona 0:3
# 2008-01-20 | Barcelona - Racing Santander 1:0
# 2008-01-27 | Athletic Club - Barcelona 1:1
# 2008-02-03 | Barcelona - Osasuna 1:0
# 2008-02-09 | Sevilla - Barcelona 1:1
# 2008-02-16 | Real Zaragoza - Barcelona 1:2
# 2008-02-24 | Barcelona - Levante UD 5:1
# 2008-03-01 | Atlético Madrid - Barcelona 4:2
# 2008-04-12 | Recreativo Huelva - Barcelona 2:2
# 2008-04-19 | Barcelona - Espanyol 0:0
# 2008-05-04 | Barcelona - Valencia 6:0
# 2008-05-07 | Real Madrid - Barcelona 4:1
# 2008-05-11 | Barcelona - Mallorca 2:3
# 2008-05-17 | Real Murcia CF - Barcelona 3:5
#
# Total matches for this competition: 28
# ========================================
# 2008 | Champions League (2008/2009)
#
# 2009-05-27 | Barcelona - Manchester United 2:0
#
# Total matches for this competition: 1
# ========================================
# 2008 | La Liga (2008/2009)
#
# 2008-08-31 | CD Numancia de Soria - Barcelona 1:0
# 2008-09-13 | Barcelona - Racing Santander 1:1
# 2008-09-21 | Sporting Gijón - Barcelona 1:6
# 2008-09-24 | Barcelona - Real Betis 3:2
# 2008-09-27 | Espanyol - Barcelona 1:2
# 2008-10-04 | Barcelona - Atlético Madrid 6:1
# 2008-10-25 | Barcelona - Almería 5:0
# 2008-11-01 | Málaga - Barcelona 1:4
# 2008-11-08 | Barcelona - Real Valladolid 6:0
# 2008-11-16 | Recreativo Huelva - Barcelona 0:2
# 2008-11-29 | Sevilla - Barcelona 0:3
# 2008-12-06 | Barcelona - Valencia 4:0
# 2008-12-13 | Barcelona - Real Madrid 2:0
# 2008-12-21 | Villarreal - Barcelona 1:2
# 2009-01-11 | Osasuna - Barcelona 2:3
# 2009-01-17 | Barcelona - RC Deportivo La Coruña 5:0
# 2009-01-24 | Barcelona - CD Numancia de Soria 4:1
# 2009-02-01 | Racing Santander - Barcelona 1:2
# 2009-02-08 | Barcelona - Sporting Gijón 3:1
# 2009-02-14 | Real Betis - Barcelona 2:2
# 2009-02-21 | Barcelona - Espanyol 1:2
# 2009-03-01 | Atlético Madrid - Barcelona 4:3
# 2009-03-07 | Barcelona - Athletic Club 2:0
# 2009-03-15 | Almería - Barcelona 0:2
# 2009-03-22 | Barcelona - Málaga 6:0
# 2009-04-04 | Real Valladolid - Barcelona 0:1
# 2009-04-11 | Barcelona - Recreativo Huelva 2:0
# 2009-04-18 | Getafe - Barcelona 0:1
# 2009-04-25 | Valencia - Barcelona 2:2
# 2009-05-02 | Real Madrid - Barcelona 2:6
# 2009-05-10 | Barcelona - Villarreal 3:3
#
# Total matches for this competition: 31
# ========================================
# 2009 | La Liga (2009/2010)
#
# 2009-09-12 | Getafe - Barcelona 0:2
# 2009-09-19 | Barcelona - Atlético Madrid 5:2
# 2009-09-22 | Racing Santander - Barcelona 1:4
# 2009-09-26 | Málaga - Barcelona 0:2
# 2009-10-03 | Barcelona - Almería 1:0
# 2009-10-17 | Valencia - Barcelona 0:0
# 2009-10-25 | Barcelona - Real Zaragoza 6:1
# 2009-10-31 | Osasuna - Barcelona 1:1
# 2009-11-07 | Barcelona - Mallorca 4:2
# 2009-11-21 | Athletic Club - Barcelona 1:1
# 2009-11-29 | Barcelona - Real Madrid 1:0
# 2009-12-02 | Xerez - Barcelona 0:2
# 2009-12-05 | RC Deportivo La Coruña - Barcelona 1:3
# 2010-01-10 | Tenerife - Barcelona 0:5
# 2010-01-16 | Barcelona - Sevilla 4:0
# 2010-01-23 | Real Valladolid - Barcelona 0:3
# 2010-01-30 | Sporting Gijón - Barcelona 0:1
# 2010-02-06 | Barcelona - Getafe 2:1
# 2010-02-14 | Atlético Madrid - Barcelona 2:1
# 2010-02-20 | Barcelona - Racing Santander 4:0
# 2010-02-27 | Barcelona - Málaga 2:1
# 2010-03-06 | Almería - Barcelona 2:2
# 2010-03-14 | Barcelona - Valencia 3:0
# 2010-03-21 | Real Zaragoza - Barcelona 2:4
# 2010-03-24 | Barcelona - Osasuna 2:0
# 2010-03-27 | Mallorca - Barcelona 0:1
# 2010-04-03 | Barcelona - Athletic Club 4:1
# 2010-04-10 | Real Madrid - Barcelona 0:2
# 2010-04-14 | Barcelona - RC Deportivo La Coruña 3:0
# 2010-04-17 | Espanyol - Barcelona 0:0
# 2010-04-24 | Barcelona - Xerez 3:1
# 2010-05-01 | Villarreal - Barcelona 1:4
# 2010-05-04 | Barcelona - Tenerife 4:1
# 2010-05-08 | Sevilla - Barcelona 2:3
# 2010-05-16 | Barcelona - Real Valladolid 4:0
#
# Total matches for this competition: 35
# ========================================
# 2009 | Champions League (2009/2010)
#
# 2010-05-22 | Bayern Munich - Inter Milan 0:2
#
# Total matches for this competition: 1
# ========================================
# 2010 | La Liga (2010/2011)
#
# 2010-08-29 | Racing Santander - Barcelona 0:3
# 2010-09-11 | Barcelona - Hércules 0:2
# 2010-09-19 | Atlético Madrid - Barcelona 1:2
# 2010-10-03 | Barcelona - Mallorca 1:1
# 2010-10-16 | Barcelona - Valencia 2:1
# 2010-10-23 | Real Zaragoza - Barcelona 0:2
# 2010-10-30 | Barcelona - Sevilla 5:0
# 2010-11-07 | Getafe - Barcelona 1:3
# 2010-11-13 | Barcelona - Villarreal 3:1
# 2010-11-20 | Almería - Barcelona 0:8
# 2010-11-29 | Barcelona - Real Madrid 5:0
# 2010-12-04 | Osasuna - Barcelona 0:3
# 2010-12-12 | Barcelona - Real Sociedad 5:0
# 2010-12-18 | Espanyol - Barcelona 1:5
# 2011-01-08 | RC Deportivo La Coruña - Barcelona 0:4
# 2011-01-16 | Barcelona - Málaga 4:1
# 2011-01-22 | Barcelona - Racing Santander 3:0
# 2011-01-29 | Hércules - Barcelona 0:3
# 2011-02-05 | Barcelona - Atlético Madrid 3:0
# 2011-02-12 | Sporting Gijón - Barcelona 1:1
# 2011-02-20 | Barcelona - Athletic Club 2:1
# 2011-02-26 | Mallorca - Barcelona 0:3
# 2011-03-02 | Valencia - Barcelona 0:1
# 2011-03-05 | Barcelona - Real Zaragoza 1:0
# 2011-03-13 | Sevilla - Barcelona 1:1
# 2011-03-19 | Barcelona - Getafe 2:1
# 2011-04-02 | Villarreal - Barcelona 0:1
# 2011-04-09 | Barcelona - Almería 3:1
# 2011-04-16 | Real Madrid - Barcelona 1:1
# 2011-04-23 | Barcelona - Osasuna 2:0
# 2011-04-30 | Real Sociedad - Barcelona 2:1
# 2011-05-08 | Barcelona - Espanyol 2:0
# 2011-05-11 | Levante UD - Barcelona 1:1
#
# Total matches for this competition: 33
# ========================================
# 2010 | Champions League (2010/2011)
#
# 2011-05-28 | Barcelona - Manchester United 3:1
#
# Total matches for this competition: 1
# ========================================
# 2011 | Champions League (2011/2012)
#
# 2012-05-19 | Bayern Munich - Chelsea 1:1
#
# Total matches for this competition: 1
# ========================================
# 2011 | La Liga (2011/2012)
#
# 2011-08-29 | Barcelona - Villarreal 5:0
# 2011-09-10 | Real Sociedad - Barcelona 2:2
# 2011-09-17 | Barcelona - Osasuna 8:0
# 2011-09-21 | Valencia - Barcelona 2:2
# 2011-09-24 | Barcelona - Atlético Madrid 5:0
# 2011-10-02 | Sporting Gijón - Barcelona 0:1
# 2011-10-15 | Barcelona - Racing Santander 3:0
# 2011-10-22 | Barcelona - Sevilla 0:0
# 2011-10-25 | Granada - Barcelona 0:1
# 2011-10-29 | Barcelona - Mallorca 5:0
# 2011-11-06 | Athletic Club - Barcelona 2:2
# 2011-11-19 | Barcelona - Real Zaragoza 4:0
# 2011-11-26 | Getafe - Barcelona 1:0
# 2011-11-29 | Barcelona - Rayo Vallecano 4:0
# 2011-12-03 | Barcelona - Levante UD 5:0
# 2011-12-10 | Real Madrid - Barcelona 1:3
# 2012-01-08 | Espanyol - Barcelona 1:1
# 2012-01-15 | Barcelona - Real Betis 4:2
# 2012-01-22 | Málaga - Barcelona 1:4
# 2012-01-28 | Villarreal - Barcelona 0:0
# 2012-02-04 | Barcelona - Real Sociedad 2:1
# 2012-02-11 | Osasuna - Barcelona 3:2
# 2012-02-19 | Barcelona - Valencia 5:1
# 2012-02-26 | Atlético Madrid - Barcelona 1:2
# 2012-03-11 | Racing Santander - Barcelona 0:2
# 2012-03-17 | Sevilla - Barcelona 0:2
# 2012-03-20 | Barcelona - Granada 5:3
# 2012-03-24 | Mallorca - Barcelona 0:2
# 2012-03-31 | Barcelona - Athletic Club 2:0
# 2012-04-07 | Real Zaragoza - Barcelona 1:4
# 2012-04-10 | Barcelona - Getafe 4:0
# 2012-04-14 | Levante UD - Barcelona 1:2
# 2012-04-21 | Barcelona - Real Madrid 1:2
# 2012-04-29 | Rayo Vallecano - Barcelona 0:7
# 2012-05-02 | Barcelona - Málaga 4:1
# 2012-05-05 | Barcelona - Espanyol 4:0
# 2012-05-12 | Real Betis - Barcelona 2:2
#
# Total matches for this competition: 37
# ========================================
# 2012 | Champions League (2012/2013)
#
# 2013-05-25 | Borussia Dortmund - Bayern Munich 1:2
#
# Total matches for this competition: 1
# ========================================
# 2012 | La Liga (2012/2013)
#
# 2012-08-19 | Barcelona - Real Sociedad 5:1
# 2012-08-26 | Osasuna - Barcelona 1:2
# 2012-09-02 | Barcelona - Valencia 1:0
# 2012-09-15 | Getafe - Barcelona 1:4
# 2012-09-22 | Barcelona - Granada 2:0
# 2012-09-29 | Sevilla - Barcelona 2:3
# 2012-10-07 | Barcelona - Real Madrid 2:2
# 2012-10-20 | RC Deportivo La Coruña - Barcelona 4:5
# 2012-10-27 | Rayo Vallecano - Barcelona 0:5
# 2012-11-03 | Barcelona - Celta Vigo 3:1
# 2012-11-11 | Mallorca - Barcelona 2:4
# 2012-11-17 | Barcelona - Real Zaragoza 3:1
# 2012-11-25 | Levante UD - Barcelona 0:4
# 2012-12-01 | Barcelona - Athletic Club 5:1
# 2012-12-09 | Real Betis - Barcelona 1:2
# 2012-12-16 | Barcelona - Atlético Madrid 4:1
# 2012-12-22 | Real Valladolid - Barcelona 1:3
# 2013-01-06 | Barcelona - Espanyol 4:0
# 2013-01-13 | Málaga - Barcelona 1:3
# 2013-01-19 | Real Sociedad - Barcelona 3:2
# 2013-01-27 | Barcelona - Osasuna 5:1
# 2013-02-03 | Valencia - Barcelona 1:1
# 2013-02-10 | Barcelona - Getafe 6:1
# 2013-02-16 | Granada - Barcelona 1:2
# 2013-02-23 | Barcelona - Sevilla 2:1
# 2013-03-02 | Real Madrid - Barcelona 2:1
# 2013-03-09 | Barcelona - RC Deportivo La Coruña 2:0
# 2013-03-17 | Barcelona - Rayo Vallecano 3:1
# 2013-03-30 | Celta Vigo - Barcelona 2:2
# 2013-04-27 | Athletic Club - Barcelona 2:2
# 2013-05-05 | Barcelona - Real Betis 4:2
# 2013-05-12 | Atlético Madrid - Barcelona 1:2
#
# Total matches for this competition: 32
# ========================================
# 2013 | La Liga (2013/2014)
#
# 2013-08-18 | Barcelona - Levante UD 7:0
# 2013-09-01 | Valencia - Barcelona 2:3
# 2013-09-14 | Barcelona - Sevilla 3:2
# 2013-09-21 | Rayo Vallecano - Barcelona 0:4
# 2013-09-24 | Barcelona - Real Sociedad 4:1
# 2013-09-28 | Almería - Barcelona 0:2
# 2013-10-19 | Osasuna - Barcelona 0:0
# 2013-10-26 | Barcelona - Real Madrid 2:1
# 2013-10-29 | Celta Vigo - Barcelona 0:3
# 2013-11-01 | Barcelona - Espanyol 1:0
# 2013-11-10 | Real Betis - Barcelona 1:4
# 2014-01-11 | Atlético Madrid - Barcelona 0:0
# 2014-01-19 | Levante UD - Barcelona 1:1
# 2014-01-26 | Barcelona - Málaga 3:0
# 2014-02-01 | Barcelona - Valencia 2:3
# 2014-02-09 | Sevilla - Barcelona 1:4
# 2014-02-15 | Barcelona - Rayo Vallecano 6:0
# 2014-02-22 | Real Sociedad - Barcelona 3:1
# 2014-03-02 | Barcelona - Almería 4:1
# 2014-03-08 | Real Valladolid - Barcelona 1:0
# 2014-03-16 | Barcelona - Osasuna 7:0
# 2014-03-23 | Real Madrid - Barcelona 3:4
# 2014-03-26 | Barcelona - Celta Vigo 3:0
# 2014-03-29 | Espanyol - Barcelona 0:1
# 2014-04-05 | Barcelona - Real Betis 3:1
# 2014-04-12 | Granada - Barcelona 1:0
# 2014-04-20 | Barcelona - Athletic Club 2:1
# 2014-04-27 | Villarreal - Barcelona 2:3
# 2014-05-03 | Barcelona - Getafe 2:2
# 2014-05-11 | Elche - Barcelona 0:0
# 2014-05-17 | Barcelona - Atlético Madrid 1:1
#
# Total matches for this competition: 31
# ========================================
# 2013 | Champions League (2013/2014)
#
# 2014-05-24 | Real Madrid - Atlético Madrid 4:1
#
# Total matches for this competition: 1
# ========================================
# 2014 | Champions League (2014/2015)
#
# 2015-06-06 | Juventus - Barcelona 1:3
#
# Total matches for this competition: 1
# ========================================
# 2014 | La Liga (2014/2015)
#
# 2014-08-24 | Barcelona - Elche 3:0
# 2014-08-31 | Villarreal - Barcelona 0:1
# 2014-09-13 | Barcelona - Athletic Club 2:0
# 2014-09-21 | Levante UD - Barcelona 0:5
# 2014-09-24 | Málaga - Barcelona 0:0
# 2014-09-27 | Barcelona - Granada 6:0
# 2014-10-04 | Rayo Vallecano - Barcelona 0:2
# 2014-10-18 | Barcelona - Eibar 3:0
# 2014-10-25 | Real Madrid - Barcelona 3:1
# 2014-11-01 | Barcelona - Celta Vigo 0:1
# 2014-11-08 | Almería - Barcelona 1:2
# 2014-11-22 | Barcelona - Sevilla 5:1
# 2014-11-30 | Valencia - Barcelona 0:1
# 2014-12-07 | Barcelona - Espanyol 5:1
# 2014-12-13 | Getafe - Barcelona 0:0
# 2014-12-20 | Barcelona - Córdoba CF 5:0
# 2015-01-04 | Real Sociedad - Barcelona 1:0
# 2015-01-11 | Barcelona - Atlético Madrid 3:1
# 2015-01-18 | RC Deportivo La Coruña - Barcelona 0:4
# 2015-01-24 | Elche - Barcelona 0:6
# 2015-02-01 | Barcelona - Villarreal 3:2
# 2015-02-08 | Athletic Club - Barcelona 2:5
# 2015-02-15 | Barcelona - Levante UD 5:0
# 2015-02-21 | Barcelona - Málaga 0:1
# 2015-02-28 | Granada - Barcelona 1:3
# 2015-03-08 | Barcelona - Rayo Vallecano 6:1
# 2015-03-14 | Eibar - Barcelona 0:2
# 2015-03-22 | Barcelona - Real Madrid 2:1
# 2015-04-05 | Celta Vigo - Barcelona 0:1
# 2015-04-08 | Barcelona - Almería 4:0
# 2015-04-11 | Sevilla - Barcelona 2:2
# 2015-04-18 | Barcelona - Valencia 2:0
# 2015-04-25 | Espanyol - Barcelona 0:2
# 2015-04-28 | Barcelona - Getafe 6:0
# 2015-05-02 | Córdoba CF - Barcelona 0:8
# 2015-05-09 | Barcelona - Real Sociedad 2:0
# 2015-05-17 | Atlético Madrid - Barcelona 0:1
# 2015-05-23 | Barcelona - RC Deportivo La Coruña 2:2
#
# Total matches for this competition: 38
# ========================================
# 2015 | 1. Bundesliga (2015/2016)
#
# 2015-08-14 | Bayern Munich - Hamburger SV 5:0
# 2015-08-15 | Augsburg - Hertha Berlin 0:1
# 2015-08-15 | Bayer Leverkusen - Hoffenheim 2:1
# 2015-08-15 | Werder Bremen - Schalke 04 0:3
# 2015-08-15 | Darmstadt 98 - Hannover 96 2:2
# 2015-08-15 | FSV Mainz 05 - Ingolstadt 0:1
# 2015-08-15 | Borussia Dortmund - Borussia Mönchengladbach 4:0
# 2015-08-16 | Wolfsburg - Eintracht Frankfurt 2:1
# 2015-08-16 | VfB Stuttgart - FC Köln 1:3
# 2015-08-21 | Hertha Berlin - Werder Bremen 1:1
# 2015-08-22 | Schalke 04 - Darmstadt 98 1:1
# 2015-08-22 | Hamburger SV - VfB Stuttgart 3:2
# 2015-08-22 | FC Köln - Wolfsburg 1:1
# 2015-08-22 | Hoffenheim - Bayern Munich 1:2
# 2015-08-22 | Hannover 96 - Bayer Leverkusen 0:1
# 2015-08-22 | Eintracht Frankfurt - Augsburg 1:1
# 2015-08-23 | Borussia Mönchengladbach - FSV Mainz 05 1:2
# 2015-08-23 | Ingolstadt - Borussia Dortmund 0:4
# 2015-08-28 | Wolfsburg - Schalke 04 3:0
# 2015-08-29 | FC Köln - Hamburger SV 2:1
# 2015-08-29 | VfB Stuttgart - Eintracht Frankfurt 1:4
# 2015-08-29 | Bayern Munich - Bayer Leverkusen 3:0
# 2015-08-29 | Darmstadt 98 - Hoffenheim 0:0
# 2015-08-29 | Augsburg - Ingolstadt 0:1
# 2015-08-29 | FSV Mainz 05 - Hannover 96 3:0
# 2015-08-30 | Borussia Dortmund - Hertha Berlin 3:1
# 2015-08-30 | Werder Bremen - Borussia Mönchengladbach 2:1
# 2015-09-11 | Borussia Mönchengladbach - Hamburger SV 0:3
# 2015-09-12 | Hannover 96 - Borussia Dortmund 2:4
# 2015-09-12 | Hertha Berlin - VfB Stuttgart 2:1
# 2015-09-12 | Eintracht Frankfurt - FC Köln 6:2
# 2015-09-12 | Bayer Leverkusen - Darmstadt 98 0:1
# 2015-09-12 | Ingolstadt - Wolfsburg 0:0
# 2015-09-12 | Bayern Munich - Augsburg 2:1
# 2015-09-13 | Hoffenheim - Werder Bremen 1:3
# 2015-09-13 | Schalke 04 - FSV Mainz 05 2:1
# 2015-09-18 | FSV Mainz 05 - Hoffenheim 3:1
# 2015-09-19 | Darmstadt 98 - Bayern Munich 0:3
# 2015-09-19 | Hamburger SV - Eintracht Frankfurt 0:0
# 2015-09-19 | Wolfsburg - Hertha Berlin 2:0
# 2015-09-19 | FC Köln - Borussia Mönchengladbach 1:0
# 2015-09-19 | Werder Bremen - Ingolstadt 0:1
# 2015-09-20 | Borussia Dortmund - Bayer Leverkusen 3:0
# 2015-09-20 | Augsburg - Hannover 96 2:0
# 2015-09-20 | VfB Stuttgart - Schalke 04 0:1
# 2015-09-22 | Darmstadt 98 - Werder Bremen 2:1
# 2015-09-22 | Hertha Berlin - FC Köln 2:0
# 2015-09-22 | Ingolstadt - Hamburger SV 0:1
# 2015-09-22 | Bayern Munich - Wolfsburg 5:1
# 2015-09-23 | Hannover 96 - VfB Stuttgart 1:3
# 2015-09-23 | Schalke 04 - Eintracht Frankfurt 2:0
# 2015-09-23 | Bayer Leverkusen - FSV Mainz 05 1:0
# 2015-09-23 | Hoffenheim - Borussia Dortmund 1:1
# 2015-09-23 | Borussia Mönchengladbach - Augsburg 4:2
# 2015-09-25 | FC Köln - Ingolstadt 1:1
# 2015-09-26 | VfB Stuttgart - Borussia Mönchengladbach 1:3
# 2015-09-26 | Augsburg - Hoffenheim 1:3
# 2015-09-26 | Werder Bremen - Bayer Leverkusen 0:3
# 2015-09-26 | FSV Mainz 05 - Bayern Munich 0:3
# 2015-09-26 | Hamburger SV - Schalke 04 0:1
# 2015-09-26 | Wolfsburg - Hannover 96 1:1
# 2015-09-27 | Eintracht Frankfurt - Hertha Berlin 1:1
# 2015-09-27 | Borussia Dortmund - Darmstadt 98 2:2
# 2015-10-02 | Darmstadt 98 - FSV Mainz 05 2:3
# 2015-10-03 | Hoffenheim - VfB Stuttgart 2:2
# 2015-10-03 | Ingolstadt - Eintracht Frankfurt 2:0
# 2015-10-03 | Hannover 96 - Werder Bremen 1:0
# 2015-10-03 | Hertha Berlin - Hamburger SV 3:0
# 2015-10-03 | Borussia Mönchengladbach - Wolfsburg 2:0
# 2015-10-04 | Schalke 04 - FC Köln 0:3
# 2015-10-04 | Bayern Munich - Borussia Dortmund 5:1
# 2015-10-04 | Bayer Leverkusen - Augsburg 1:1
# 2015-10-16 | FSV Mainz 05 - Borussia Dortmund 0:2
# 2015-10-17 | Werder Bremen - Bayern Munich 0:1
# 2015-10-17 | Augsburg - Darmstadt 98 0:2
# 2015-10-17 | Wolfsburg - Hoffenheim 4:2
# 2015-10-17 | Schalke 04 - Hertha Berlin 2:1
# 2015-10-17 | Hamburger SV - Bayer Leverkusen 0:0
# 2015-10-17 | Eintracht Frankfurt - Borussia Mönchengladbach 1:5
# 2015-10-18 | VfB Stuttgart - Ingolstadt 1:0
# 2015-10-18 | FC Köln - Hannover 96 0:1
# 2015-10-23 | Hoffenheim - Hamburger SV 0:1
# 2015-10-24 | Bayer Leverkusen - VfB Stuttgart 4:3
# 2015-10-24 | Hannover 96 - Eintracht Frankfurt 1:2
# 2015-10-24 | FSV Mainz 05 - Werder Bremen 1:3
# 2015-10-24 | Ingolstadt - Hertha Berlin 0:1
# 2015-10-24 | Darmstadt 98 - Wolfsburg 0:1
# 2015-10-24 | Bayern Munich - FC Köln 4:0
# 2015-10-25 | Borussia Mönchengladbach - Schalke 04 3:1
# 2015-10-25 | Borussia Dortmund - Augsburg 5:1
# 2015-10-30 | Eintracht Frankfurt - Bayern Munich 0:0
# 2015-10-31 | Wolfsburg - Bayer Leverkusen 2:1
# 2015-10-31 | Hertha Berlin - Borussia Mönchengladbach 1:4
# 2015-10-31 | FC Köln - Hoffenheim 0:0
# 2015-10-31 | Werder Bremen - Borussia Dortmund 1:3
# 2015-10-31 | Augsburg - FSV Mainz 05 3:3
# 2015-10-31 | Schalke 04 - Ingolstadt 1:1
# 2015-11-01 | Hamburger SV - Hannover 96 1:2
# 2015-11-01 | VfB Stuttgart - Darmstadt 98 2:0
# 2015-11-06 | Hannover 96 - Hertha Berlin 1:3
# 2015-11-07 | Bayern Munich - VfB Stuttgart 4:0
# 2015-11-07 | Borussia Mönchengladbach - Ingolstadt 0:0
# 2015-11-07 | Hoffenheim - Eintracht Frankfurt 0:0
# 2015-11-07 | FSV Mainz 05 - Wolfsburg 2:0
# 2015-11-07 | Darmstadt 98 - Hamburger SV 1:1
# 2015-11-07 | Bayer Leverkusen - FC Köln 1:2
# 2015-11-08 | Augsburg - Werder Bremen 1:2
# 2015-11-08 | Borussia Dortmund - Schalke 04 3:2
# 2015-11-20 | Hamburger SV - Borussia Dortmund 3:1
# 2015-11-21 | VfB Stuttgart - Augsburg 0:4
# 2015-11-21 | FC Köln - FSV Mainz 05 0:0
# 2015-11-21 | Eintracht Frankfurt - Bayer Leverkusen 1:3
# 2015-11-21 | Schalke 04 - Bayern Munich 1:3
# 2015-11-21 | Wolfsburg - Werder Bremen 6:0
# 2015-11-21 | Borussia Mönchengladbach - Hannover 96 2:1
# 2015-11-22 | Ingolstadt - Darmstadt 98 3:1
# 2015-11-22 | Hertha Berlin - Hoffenheim 1:0
# 2015-11-27 | Darmstadt 98 - FC Köln 0:0
# 2015-11-28 | Hannover 96 - Ingolstadt 4:0
# 2015-11-28 | FSV Mainz 05 - Eintracht Frankfurt 2:1
# 2015-11-28 | Werder Bremen - Hamburger SV 1:3
# 2015-11-28 | Hoffenheim - Borussia Mönchengladbach 3:3
# 2015-11-28 | Bayern Munich - Hertha Berlin 2:0
# 2015-11-29 | Bayer Leverkusen - Schalke 04 1:1
# 2015-11-29 | Augsburg - Wolfsburg 0:0
# 2015-11-29 | Borussia Dortmund - VfB Stuttgart 4:1
# 2015-12-04 | Schalke 04 - Hannover 96 3:1
# 2015-12-05 | Hertha Berlin - Bayer Leverkusen 2:1
# 2015-12-05 | Hamburger SV - FSV Mainz 05 1:3
# 2015-12-05 | Borussia Mönchengladbach - Bayern Munich 3:1
# 2015-12-05 | Wolfsburg - Borussia Dortmund 1:2
# 2015-12-05 | Ingolstadt - Hoffenheim 1:1
# 2015-12-05 | FC Köln - Augsburg 0:1
# 2015-12-06 | Eintracht Frankfurt - Darmstadt 98 0:1
# 2015-12-06 | VfB Stuttgart - Werder Bremen 1:1
# 2015-12-11 | FSV Mainz 05 - VfB Stuttgart 0:0
# 2015-12-12 | Darmstadt 98 - Hertha Berlin 0:4
# 2015-12-12 | Bayer Leverkusen - Borussia Mönchengladbach 5:0
# 2015-12-12 | Hoffenheim - Hannover 96 1:0
# 2015-12-12 | Wolfsburg - Hamburger SV 1:1
# 2015-12-12 | Bayern Munich - Ingolstadt 2:0
# 2015-12-12 | Werder Bremen - FC Köln 1:1
# 2015-12-13 | Augsburg - Schalke 04 2:1
# 2015-12-13 | Borussia Dortmund - Eintracht Frankfurt 4:1
# 2015-12-18 | Schalke 04 - Hoffenheim 1:0
# 2015-12-19 | Hamburger SV - Augsburg 0:1
# 2015-12-19 | Eintracht Frankfurt - Werder Bremen 2:1
# 2015-12-19 | FC Köln - Borussia Dortmund 2:1
# 2015-12-19 | Hannover 96 - Bayern Munich 0:1
# 2015-12-19 | VfB Stuttgart - Wolfsburg 3:1
# 2015-12-19 | Ingolstadt - Bayer Leverkusen 0:1
# 2015-12-20 | Borussia Mönchengladbach - Darmstadt 98 3:2
# 2015-12-20 | Hertha Berlin - FSV Mainz 05 2:0
# 2016-01-22 | Hamburger SV - Bayern Munich 1:2
# 2016-01-23 | Hannover 96 - Darmstadt 98 1:2
# 2016-01-23 | Borussia Mönchengladbach - Borussia Dortmund 1:3
# 2016-01-23 | Ingolstadt - FSV Mainz 05 1:0
# 2016-01-23 | Hoffenheim - Bayer Leverkusen 1:1
# 2016-01-23 | Hertha Berlin - Augsburg 0:0
# 2016-01-23 | FC Köln - VfB Stuttgart 1:3
# 2016-01-24 | Eintracht Frankfurt - Wolfsburg 3:2
# 2016-01-24 | Schalke 04 - Werder Bremen 1:3
# 2016-01-29 | FSV Mainz 05 - Borussia Mönchengladbach 1:0
# 2016-01-30 | VfB Stuttgart - Hamburger SV 2:1
# 2016-01-30 | Darmstadt 98 - Schalke 04 0:2
# 2016-01-30 | Werder Bremen - Hertha Berlin 3:3
# 2016-01-30 | Augsburg - Eintracht Frankfurt 0:0
# 2016-01-30 | Bayer Leverkusen - Hannover 96 3:0
# 2016-01-30 | Borussia Dortmund - Ingolstadt 2:0
# 2016-01-31 | Bayern Munich - Hoffenheim 2:0
# 2016-01-31 | Wolfsburg - FC Köln 1:1
# 2016-02-05 | Borussia Mönchengladbach - Werder Bremen 5:1
# 2016-02-06 | Ingolstadt - Augsburg 2:1
# 2016-02-06 | Hertha Berlin - Borussia Dortmund 0:0
# 2016-02-06 | Eintracht Frankfurt - VfB Stuttgart 2:4
# 2016-02-06 | Schalke 04 - Wolfsburg 3:0
# 2016-02-06 | Bayer Leverkusen - Bayern Munich 0:0
# 2016-02-06 | Hannover 96 - FSV Mainz 05 0:1
# 2016-02-07 | Hoffenheim - Darmstadt 98 0:2
# 2016-02-07 | Hamburger SV - FC Köln 1:1
# 2016-02-12 | FSV Mainz 05 - Schalke 04 2:1
# 2016-02-13 | Wolfsburg - Ingolstadt 2:0
# 2016-02-13 | Darmstadt 98 - Bayer Leverkusen 1:2
# 2016-02-13 | VfB Stuttgart - Hertha Berlin 2:0
# 2016-02-13 | Borussia Dortmund - Hannover 96 1:0
# 2016-02-13 | FC Köln - Eintracht Frankfurt 3:1
# 2016-02-13 | Werder Bremen - Hoffenheim 1:1
# 2016-02-14 | Augsburg - Bayern Munich 1:3
# 2016-02-14 | Hamburger SV - Borussia Mönchengladbach 3:2
# 2016-02-19 | Eintracht Frankfurt - Hamburger SV 0:0
# 2016-02-20 | Ingolstadt - Werder Bremen 2:0
# 2016-02-20 | Borussia Mönchengladbach - FC Köln 1:0
# 2016-02-20 | Hertha Berlin - Wolfsburg 1:1
# 2016-02-20 | Hoffenheim - FSV Mainz 05 3:2
# 2016-02-20 | Bayern Munich - Darmstadt 98 3:1
# 2016-02-21 | Hannover 96 - Augsburg 0:1
# 2016-02-21 | Schalke 04 - VfB Stuttgart 1:1
# 2016-02-21 | Bayer Leverkusen - Borussia Dortmund 0:1
# 2016-02-26 | FC Köln - Hertha Berlin 0:1
# 2016-02-27 | Hamburger SV - Ingolstadt 1:1
# 2016-02-27 | VfB Stuttgart - Hannover 96 1:2
# 2016-02-27 | Werder Bremen - Darmstadt 98 2:2
# 2016-02-27 | Wolfsburg - Bayern Munich 0:2
# 2016-02-28 | Augsburg - Borussia Mönchengladbach 2:2
# 2016-02-28 | FSV Mainz 05 - Bayer Leverkusen 3:1
# 2016-02-28 | Borussia Dortmund - Hoffenheim 3:1
# 2016-02-28 | Eintracht Frankfurt - Schalke 04 0:0
# 2016-03-01 | Hannover 96 - Wolfsburg 0:4
# 2016-03-01 | Ingolstadt - FC Köln 1:1
# 2016-03-02 | Bayern Munich - FSV Mainz 05 1:2
# 2016-03-02 | Schalke 04 - Hamburger SV 3:2
# 2016-03-02 | Bayer Leverkusen - Werder Bremen 1:4
# 2016-03-02 | Hoffenheim - Augsburg 2:1
# 2016-03-02 | Hertha Berlin - Eintracht Frankfurt 2:0
# 2016-03-02 | Darmstadt 98 - Borussia Dortmund 0:2
# 2016-03-02 | Borussia Mönchengladbach - VfB Stuttgart 4:0
# 2016-03-05 | FC Köln - Schalke 04 1:3
# 2016-03-05 | Borussia Dortmund - Bayern Munich 0:0
# 2016-03-05 | Eintracht Frankfurt - Ingolstadt 1:1
# 2016-03-05 | Werder Bremen - Hannover 96 4:1
# 2016-03-05 | Augsburg - Bayer Leverkusen 3:3
# 2016-03-05 | VfB Stuttgart - Hoffenheim 5:1
# 2016-03-05 | Wolfsburg - Borussia Mönchengladbach 2:1
# 2016-03-06 | FSV Mainz 05 - Darmstadt 98 0:0
# 2016-03-06 | Hamburger SV - Hertha Berlin 2:0
# 2016-03-11 | Hertha Berlin - Schalke 04 2:0
# 2016-03-12 | Hannover 96 - FC Köln 0:2
# 2016-03-12 | Bayern Munich - Werder Bremen 5:0
# 2016-03-12 | Borussia Mönchengladbach - Eintracht Frankfurt 3:0
# 2016-03-12 | Darmstadt 98 - Augsburg 2:2
# 2016-03-12 | Hoffenheim - Wolfsburg 1:0
# 2016-03-12 | Ingolstadt - VfB Stuttgart 3:3
# 2016-03-13 | Borussia Dortmund - FSV Mainz 05 2:0
# 2016-03-13 | Bayer Leverkusen - Hamburger SV 1:0
# 2016-03-18 | Schalke 04 - Borussia Mönchengladbach 2:1
# 2016-03-19 | Hamburger SV - Hoffenheim 1:3
# 2016-03-19 | Wolfsburg - Darmstadt 98 1:1
# 2016-03-19 | Werder Bremen - FSV Mainz 05 1:1
# 2016-03-19 | Hertha Berlin - Ingolstadt 2:1
# 2016-03-19 | Eintracht Frankfurt - Hannover 96 1:0
# 2016-03-19 | FC Köln - Bayern Munich 0:1
# 2016-03-20 | VfB Stuttgart - Bayer Leverkusen 0:2
# 2016-03-20 | Augsburg - Borussia Dortmund 1:3
# 2016-04-01 | Bayer Leverkusen - Wolfsburg 3:0
# 2016-04-02 | FSV Mainz 05 - Augsburg 4:2
# 2016-04-02 | Hannover 96 - Hamburger SV 0:3
# 2016-04-02 | Darmstadt 98 - VfB Stuttgart 2:2
# 2016-04-02 | Borussia Dortmund - Werder Bremen 3:2
# 2016-04-02 | Ingolstadt - Schalke 04 3:0
# 2016-04-02 | Bayern Munich - Eintracht Frankfurt 1:0
# 2016-04-03 | Hoffenheim - FC Köln 1:1
# 2016-04-03 | Borussia Mönchengladbach - Hertha Berlin 5:0
# 2016-04-08 | Hertha Berlin - Hannover 96 2:2
# 2016-04-09 | Hamburger SV - Darmstadt 98 1:2
# 2016-04-09 | Ingolstadt - Borussia Mönchengladbach 1:0
# 2016-04-09 | VfB Stuttgart - Bayern Munich 1:3
# 2016-04-09 | Eintracht Frankfurt - Hoffenheim 0:2
# 2016-04-09 | Wolfsburg - FSV Mainz 05 1:1
# 2016-04-09 | Werder Bremen - Augsburg 1:2
# 2016-04-10 | Schalke 04 - Borussia Dortmund 2:2
# 2016-04-10 | FC Köln - Bayer Leverkusen 0:2
# 2016-04-15 | Hannover 96 - Borussia Mönchengladbach 2:0
# 2016-04-16 | Werder Bremen - Wolfsburg 3:2
# 2016-04-16 | Hoffenheim - Hertha Berlin 2:1
# 2016-04-16 | Darmstadt 98 - Ingolstadt 2:0
# 2016-04-16 | Bayer Leverkusen - Eintracht Frankfurt 3:0
# 2016-04-16 | Augsburg - VfB Stuttgart 1:0
# 2016-04-16 | Bayern Munich - Schalke 04 3:0
# 2016-04-17 | FSV Mainz 05 - FC Köln 2:3
# 2016-04-17 | Borussia Dortmund - Hamburger SV 3:0
# 2016-04-22 | Hamburger SV - Werder Bremen 2:1
# 2016-04-23 | Wolfsburg - Augsburg 0:2
# 2016-04-23 | Schalke 04 - Bayer Leverkusen 2:3
# 2016-04-23 | Hertha Berlin - Bayern Munich 0:2
# 2016-04-23 | Ingolstadt - Hannover 96 2:2
# 2016-04-23 | FC Köln - Darmstadt 98 4:1
# 2016-04-23 | VfB Stuttgart - Borussia Dortmund 0:3
# 2016-04-24 | Borussia Mönchengladbach - Hoffenheim 3:1
# 2016-04-24 | Eintracht Frankfurt - FSV Mainz 05 2:1
# 2016-04-29 | Augsburg - FC Köln 0:0
# 2016-04-30 | Bayern Munich - Borussia Mönchengladbach 1:1
# 2016-04-30 | Borussia Dortmund - Wolfsburg 5:1
# 2016-04-30 | Hannover 96 - Schalke 04 1:3
# 2016-04-30 | FSV Mainz 05 - Hamburger SV 0:0
# 2016-04-30 | Darmstadt 98 - Eintracht Frankfurt 1:2
# 2016-04-30 | Bayer Leverkusen - Hertha Berlin 2:1
# 2016-04-30 | Hoffenheim - Ingolstadt 2:1
# 2016-05-02 | Werder Bremen - VfB Stuttgart 6:2
# 2016-05-07 | FC Köln - Werder Bremen 0:0
# 2016-05-07 | Hertha Berlin - Darmstadt 98 1:2
# 2016-05-07 | VfB Stuttgart - FSV Mainz 05 1:3
# 2016-05-07 | Hamburger SV - Wolfsburg 0:1
# 2016-05-07 | Borussia Mönchengladbach - Bayer Leverkusen 2:1
# 2016-05-07 | Schalke 04 - Augsburg 1:1
# 2016-05-07 | Ingolstadt - Bayern Munich 1:2
# 2016-05-07 | Hannover 96 - Hoffenheim 1:0
# 2016-05-07 | Eintracht Frankfurt - Borussia Dortmund 1:0
# 2016-05-14 | Wolfsburg - VfB Stuttgart 3:1
# 2016-05-14 | Werder Bremen - Eintracht Frankfurt 1:0
# 2016-05-14 | FSV Mainz 05 - Hertha Berlin 0:0
# 2016-05-14 | Bayern Munich - Hannover 96 3:1
# 2016-05-14 | Darmstadt 98 - Borussia Mönchengladbach 0:2
# 2016-05-14 | Borussia Dortmund - FC Köln 2:2
# 2016-05-14 | Bayer Leverkusen - Ingolstadt 3:2
# 2016-05-14 | Augsburg - Hamburger SV 1:3
# 2016-05-14 | Hoffenheim - Schalke 04 1:4
#
# Total matches for this competition: 306
# ========================================
# 2015 | Ligue 1 (2015/2016)
#
# 2015-08-07 | Lille - Paris Saint-Germain 0:1
# 2015-08-08 | Marseille - Caen 0:1
# 2015-08-08 | Troyes - Gazélec Ajaccio 0:0
# 2015-08-08 | Nantes - Guingamp 1:0
# 2015-08-08 | OGC Nice - AS Monaco 1:2
# 2015-08-08 | Montpellier - Angers 0:2
# 2015-08-08 | Bastia - Rennes 2:1
# 2015-08-09 | Bordeaux - Stade de Reims 1:2
# 2015-08-09 | Toulouse - Saint-Étienne 2:1
# 2015-08-09 | Lyon - Lorient 0:0
# 2015-08-14 | AS Monaco - Lille 0:0
# 2015-08-15 | Rennes - Montpellier 1:0
# 2015-08-15 | Caen - Toulouse 1:0
# 2015-08-15 | Guingamp - Lyon 0:1
# 2015-08-15 | Saint-Étienne - Bordeaux 1:1
# 2015-08-15 | Troyes - OGC Nice 3:3
# 2015-08-15 | Angers - Nantes 0:0
# 2015-08-16 | Paris Saint-Germain - Gazélec Ajaccio 2:0
# 2015-08-16 | Stade de Reims - Marseille 1:0
# 2015-08-16 | Lorient - Bastia 1:1
# 2015-08-21 | Montpellier - Paris Saint-Germain 0:1
# 2015-08-22 | Bastia - Guingamp 3:0
# 2015-08-22 | Lyon - Rennes 1:2
# 2015-08-22 | Nantes - Stade de Reims 1:0
# 2015-08-22 | Gazélec Ajaccio - Angers 0:2
# 2015-08-22 | OGC Nice - Caen 2:1
# 2015-08-22 | Toulouse - AS Monaco 1:1
# 2015-08-23 | Lorient - Saint-Étienne 0:1
# 2015-08-23 | Marseille - Troyes 6:0
# 2015-08-23 | Lille - Bordeaux 0:0
# 2015-08-28 | Guingamp - Marseille 2:0
# 2015-08-29 | Stade de Reims - Lorient 4:1
# 2015-08-29 | Lille - Gazélec Ajaccio 1:0
# 2015-08-29 | Angers - OGC Nice 1:1
# 2015-08-29 | Caen - Lyon 0:4
# 2015-08-29 | Rennes - Toulouse 3:1
# 2015-08-29 | Troyes - Montpellier 0:0
# 2015-08-30 | Saint-Étienne - Bastia 2:1
# 2015-08-30 | Bordeaux - Nantes 2:0
# 2015-08-30 | AS Monaco - Paris Saint-Germain 0:3
# 2015-09-11 | Paris Saint-Germain - Bordeaux 2:2
# 2015-09-12 | Montpellier - Saint-Étienne 1:2
# 2015-09-12 | Lorient - Angers 3:1
# 2015-09-12 | Troyes - Caen 1:3
# 2015-09-12 | Lyon - Lille 0:0
# 2015-09-12 | Toulouse - Stade de Reims 2:2
# 2015-09-12 | OGC Nice - Guingamp 0:1
# 2015-09-13 | Nantes - Rennes 0:2
# 2015-09-13 | Marseille - Bastia 4:1
# 2015-09-13 | Gazélec Ajaccio - AS Monaco 0:1
# 2015-09-18 | Rennes - Lille 1:1
# 2015-09-19 | Bastia - OGC Nice 1:3
# 2015-09-19 | Angers - Troyes 1:0
# 2015-09-19 | Stade de Reims - Paris Saint-Germain 1:1
# 2015-09-19 | Caen - Montpellier 2:1
# 2015-09-19 | Guingamp - Gazélec Ajaccio 2:1
# 2015-09-20 | Marseille - Lyon 1:1
# 2015-09-20 | Bordeaux - Toulouse 1:1
# 2015-09-20 | AS Monaco - Lorient 2:3
# 2015-09-20 | Saint-Étienne - Nantes 2:0
# 2015-09-22 | Paris Saint-Germain - Guingamp 3:0
# 2015-09-22 | Angers - Stade de Reims 0:0
# 2015-09-23 | Lorient - Caen 2:0
# 2015-09-23 | Gazélec Ajaccio - Rennes 1:1
# 2015-09-23 | OGC Nice - Bordeaux 6:1
# 2015-09-23 | Lyon - Bastia 2:0
# 2015-09-23 | Toulouse - Marseille 1:1
# 2015-09-23 | Troyes - Saint-Étienne 0:1
# 2015-09-24 | Montpellier - AS Monaco 2:3
# 2015-09-25 | Stade de Reims - Lille 1:0
# 2015-09-26 | Rennes - Troyes 1:1
# 2015-09-26 | Caen - Gazélec Ajaccio 2:0
# 2015-09-26 | Bastia - Toulouse 3:0
# 2015-09-26 | Nantes - Paris Saint-Germain 1:4
# 2015-09-26 | Bordeaux - Lyon 3:1
# 2015-09-27 | Marseille - Angers 1:2
# 2015-09-27 | Guingamp - AS Monaco 3:3
# 2015-09-27 | Montpellier - Lorient 2:1
# 2015-09-27 | Saint-Étienne - OGC Nice 1:4
# 2015-09-29 | Lille - Nantes 0:1
# 2015-10-02 | Lille - Montpellier 2:0
# 2015-10-03 | Angers - Bastia 1:0
# 2015-10-03 | Lyon - Stade de Reims 1:0
# 2015-10-03 | Troyes - Guingamp 0:1
# 2015-10-03 | Gazélec Ajaccio - Toulouse 2:2
# 2015-10-04 | Lorient - Bordeaux 3:2
# 2015-10-04 | Paris Saint-Germain - Marseille 2:1
# 2015-10-04 | AS Monaco - Rennes 1:1
# 2015-10-04 | Caen - Saint-Étienne 1:0
# 2015-10-16 | AS Monaco - Lyon 1:1
# 2015-10-17 | Toulouse - Angers 1:2
# 2015-10-17 | Guingamp - Lille 1:1
# 2015-10-17 | Saint-Étienne - Gazélec Ajaccio 2:0
# 2015-10-17 | Bastia - Paris Saint-Germain 0:2
# 2015-10-17 | Stade de Reims - Caen 0:1
# 2015-10-17 | Nantes - Troyes 3:0
# 2015-10-18 | Rennes - OGC Nice 1:4
# 2015-10-18 | Marseille - Lorient 1:1
# 2015-10-18 | Bordeaux - Montpellier 0:0
# 2015-10-23 | Lyon - Toulouse 3:0
# 2015-10-23 | Caen - Nantes 0:2
# 2015-10-24 | Montpellier - Bastia 2:0
# 2015-10-24 | Lorient - Rennes 1:1
# 2015-10-24 | Angers - Guingamp 0:0
# 2015-10-24 | Gazélec Ajaccio - OGC Nice 3:1
# 2015-10-25 | Lille - Marseille 1:2
# 2015-10-25 | Paris Saint-Germain - Saint-Étienne 4:1
# 2015-10-25 | Stade de Reims - AS Monaco 0:1
# 2015-10-25 | Bordeaux - Troyes 1:0
# 2015-10-30 | Rennes - Paris Saint-Germain 0:1
# 2015-10-31 | Guingamp - Lorient 2:2
# 2015-10-31 | Troyes - Lyon 0:1
# 2015-10-31 | Gazélec Ajaccio - Bordeaux 2:0
# 2015-10-31 | Bastia - Caen 1:0
# 2015-10-31 | Toulouse - Montpellier 1:1
# 2015-10-31 | Saint-Étienne - Stade de Reims 3:0
# 2015-11-01 | OGC Nice - Lille 0:0
# 2015-11-01 | AS Monaco - Angers 1:0
# 2015-11-01 | Nantes - Marseille 0:1
# 2015-11-04 | OGC Nice - Nantes 1:2
# 2015-11-06 | Angers - Rennes 0:2
# 2015-11-07 | Paris Saint-Germain - Toulouse 5:0
# 2015-11-07 | Caen - Guingamp 2:1
# 2015-11-07 | Montpellier - Nantes 2:1
# 2015-11-07 | Lorient - Troyes 4:1
# 2015-11-07 | Lille - Bastia 1:1
# 2015-11-07 | Stade de Reims - Gazélec Ajaccio 1:2
# 2015-11-08 | Marseille - OGC Nice 0:1
# 2015-11-08 | Bordeaux - AS Monaco 3:1
# 2015-11-08 | Lyon - Saint-Étienne 3:0
# 2015-11-20 | OGC Nice - Lyon 3:0
# 2015-11-21 | Guingamp - Toulouse 2:0
# 2015-11-21 | Lorient - Paris Saint-Germain 1:2
# 2015-11-21 | Troyes - Lille 1:1
# 2015-11-21 | Montpellier - Stade de Reims 3:1
# 2015-11-21 | AS Monaco - Nantes 1:0
# 2015-11-22 | Saint-Étienne - Marseille 0:2
# 2015-11-22 | Caen - Angers 0:0
# 2015-11-22 | Rennes - Bordeaux 2:2
# 2015-11-27 | Lyon - Montpellier 2:4
# 2015-11-28 | Toulouse - OGC Nice 2:0
# 2015-11-28 | Stade de Reims - Rennes 2:2
# 2015-11-28 | Paris Saint-Germain - Troyes 4:1
# 2015-11-28 | Gazélec Ajaccio - Lorient 1:1
# 2015-11-28 | Angers - Lille 2:0
# 2015-11-28 | Nantes - Bastia 0:0
# 2015-11-29 | Bordeaux - Caen 1:4
# 2015-11-29 | Saint-Étienne - Guingamp 3:0
# 2015-11-29 | Marseille - AS Monaco 3:3
# 2015-12-01 | Nantes - Lyon 0:0
# 2015-12-01 | Lorient - OGC Nice 0:0
# 2015-12-01 | Angers - Paris Saint-Germain 0:0
# 2015-12-02 | AS Monaco - Caen 1:1
# 2015-12-02 | Guingamp - Stade de Reims 1:2
# 2015-12-02 | Troyes - Toulouse 0:3
# 2015-12-02 | Montpellier - Gazélec Ajaccio 0:2
# 2015-12-02 | Lille - Saint-Étienne 1:0
# 2015-12-02 | Bastia - Bordeaux 1:0
# 2015-12-03 | Rennes - Marseille 0:1
# 2015-12-04 | OGC Nice - Paris Saint-Germain 0:3
# 2015-12-05 | Bastia - AS Monaco 1:2
# 2015-12-05 | Stade de Reims - Troyes 1:1
# 2015-12-05 | Toulouse - Lorient 2:3
# 2015-12-05 | Gazélec Ajaccio - Nantes 1:1
# 2015-12-05 | Lyon - Angers 0:2
# 2015-12-05 | Caen - Lille 1:2
# 2015-12-06 | Marseille - Montpellier 2:2
# 2015-12-06 | Bordeaux - Guingamp 1:0
# 2015-12-06 | Saint-Étienne - Rennes 1:1
# 2015-12-11 | Rennes - Caen 1:1
# 2015-12-12 | Montpellier - Guingamp 2:1
# 2015-12-12 | Lille - Lorient 3:0
# 2015-12-12 | Stade de Reims - OGC Nice 1:1
# 2015-12-12 | Troyes - Bastia 1:1
# 2015-12-12 | Nantes - Toulouse 1:1
# 2015-12-13 | Marseille - Gazélec Ajaccio 1:1
# 2015-12-13 | Angers - Bordeaux 1:1
# 2015-12-13 | Paris Saint-Germain - Lyon 5:1
# 2015-12-13 | AS Monaco - Saint-Étienne 1:0
# 2015-12-18 | OGC Nice - Montpellier 1:0
# 2015-12-19 | Toulouse - Lille 1:1
# 2015-12-19 | Caen - Paris Saint-Germain 0:3
# 2015-12-19 | Guingamp - Rennes 0:2
# 2015-12-19 | Troyes - AS Monaco 0:0
# 2015-12-19 | Lorient - Nantes 0:0
# 2015-12-19 | Bastia - Stade de Reims 2:0
# 2015-12-20 | Bordeaux - Marseille 1:1
# 2015-12-20 | Saint-Étienne - Angers 1:0
# 2015-12-20 | Gazélec Ajaccio - Lyon 2:1
# 2016-01-08 | Paris Saint-Germain - Bastia 2:0
# 2016-01-09 | Rennes - Lorient 2:2
# 2016-01-09 | AS Monaco - Gazélec Ajaccio 2:2
# 2016-01-09 | Angers - Caen 2:0
# 2016-01-09 | Montpellier - Bordeaux 0:1
# 2016-01-09 | Lyon - Troyes 4:1
# 2016-01-09 | Stade de Reims - Toulouse 1:3
# 2016-01-10 | Marseille - Guingamp 0:0
# 2016-01-10 | Lille - OGC Nice 1:1
# 2016-01-10 | Nantes - Saint-Étienne 2:1
# 2016-01-15 | OGC Nice - Angers 2:1
# 2016-01-16 | Toulouse - Paris Saint-Germain 0:1
# 2016-01-16 | Troyes - Rennes 2:4
# 2016-01-16 | Gazélec Ajaccio - Stade de Reims 2:2
# 2016-01-16 | Bordeaux - Lille 1:0
# 2016-01-16 | Bastia - Montpellier 1:0
# 2016-01-16 | Guingamp - Nantes 2:2
# 2016-01-17 | Saint-Étienne - Lyon 1:0
# 2016-01-17 | Lorient - AS Monaco 0:2
# 2016-01-17 | Caen - Marseille 1:3
# 2016-01-22 | Rennes - Gazélec Ajaccio 1:0
# 2016-01-23 | Montpellier - Caen 1:2
# 2016-01-23 | Paris Saint-Germain - Angers 5:1
# 2016-01-23 | Lille - Troyes 1:3
# 2016-01-23 | Guingamp - Bastia 1:0
# 2016-01-23 | Nantes - Bordeaux 2:2
# 2016-01-23 | OGC Nice - Lorient 2:1
# 2016-01-24 | Stade de Reims - Saint-Étienne 1:1
# 2016-01-24 | Lyon - Marseille 1:1
# 2016-01-24 | AS Monaco - Toulouse 4:0
# 2016-01-29 | Marseille - Lille 1:1
# 2016-01-30 | Angers - AS Monaco 3:0
# 2016-01-30 | Lorient - Stade de Reims 2:0
# 2016-01-30 | Gazélec Ajaccio - Montpellier 0:4
# 2016-01-30 | Toulouse - Guingamp 1:2
# 2016-01-30 | Troyes - Nantes 0:1
# 2016-01-30 | Bastia - Lyon 1:0
# 2016-01-31 | Bordeaux - Rennes 4:0
# 2016-01-31 | Caen - OGC Nice 2:0
# 2016-02-02 | Montpellier - Marseille 0:1
# 2016-02-02 | AS Monaco - Bastia 2:0
# 2016-02-03 | OGC Nice - Toulouse 1:0
# 2016-02-03 | Lille - Caen 1:0
# 2016-02-03 | Paris Saint-Germain - Lorient 3:1
# 2016-02-03 | Stade de Reims - Angers 2:1
# 2016-02-03 | Lyon - Bordeaux 3:0
# 2016-02-03 | Guingamp - Troyes 4:0
# 2016-02-03 | Nantes - Gazélec Ajaccio 3:1
# 2016-02-04 | Rennes - Saint-Étienne 0:1
# 2016-02-06 | AS Monaco - OGC Nice 1:0
# 2016-02-06 | Angers - Lyon 0:3
# 2016-02-06 | Toulouse - Nantes 0:0
# 2016-02-06 | Gazélec Ajaccio - Guingamp 0:0
# 2016-02-06 | Caen - Stade de Reims 0:2
# 2016-02-06 | Bastia - Troyes 2:0
# 2016-02-06 | Lorient - Montpellier 1:1
# 2016-02-07 | Lille - Rennes 1:1
# 2016-02-07 | Bordeaux - Saint-Étienne 1:4
# 2016-02-07 | Marseille - Paris Saint-Germain 1:2
# 2016-02-12 | Rennes - Angers 1:0
# 2016-02-13 | Guingamp - Bordeaux 2:4
# 2016-02-13 | Paris Saint-Germain - Lille 0:0
# 2016-02-13 | Stade de Reims - Bastia 0:1
# 2016-02-13 | Gazélec Ajaccio - Troyes 2:3
# 2016-02-13 | Nantes - Lorient 2:1
# 2016-02-13 | Montpellier - Toulouse 2:0
# 2016-02-14 | OGC Nice - Marseille 1:1
# 2016-02-14 | Lyon - Caen 4:1
# 2016-02-14 | Saint-Étienne - AS Monaco 1:1
# 2016-02-19 | Bordeaux - OGC Nice 0:0
# 2016-02-20 | Angers - Montpellier 2:3
# 2016-02-20 | Paris Saint-Germain - Stade de Reims 4:1
# 2016-02-20 | Lorient - Guingamp 4:3
# 2016-02-20 | Toulouse - Gazélec Ajaccio 1:1
# 2016-02-20 | AS Monaco - Troyes 3:1
# 2016-02-21 | Marseille - Saint-Étienne 1:1
# 2016-02-21 | Lille - Lyon 1:0
# 2016-02-21 | Caen - Rennes 1:0
# 2016-02-26 | OGC Nice - Bastia 0:2
# 2016-02-27 | Troyes - Lorient 0:1
# 2016-02-27 | Toulouse - Rennes 1:2
# 2016-02-27 | Stade de Reims - Bordeaux 4:1
# 2016-02-27 | Montpellier - Lille 3:0
# 2016-02-27 | Guingamp - Angers 2:2
# 2016-02-28 | Saint-Étienne - Caen 1:2
# 2016-02-28 | Nantes - AS Monaco 0:0
# 2016-02-28 | Lyon - Paris Saint-Germain 2:1
# 2016-03-04 | Caen - AS Monaco 2:2
# 2016-03-05 | Angers - Saint-Étienne 0:0
# 2016-03-05 | OGC Nice - Troyes 2:1
# 2016-03-05 | Lille - Stade de Reims 2:0
# 2016-03-05 | Paris Saint-Germain - Montpellier 0:0
# 2016-03-05 | Bordeaux - Gazélec Ajaccio 1:1
# 2016-03-05 | Bastia - Lorient 0:0
# 2016-03-06 | Marseille - Toulouse 1:1
# 2016-03-06 | Rennes - Nantes 4:1
# 2016-03-06 | Lyon - Guingamp 5:1
# 2016-03-09 | Bastia - Nantes 0:0
# 2016-03-09 | Gazélec Ajaccio - Marseille 1:1
# 2016-03-11 | AS Monaco - Stade de Reims 2:2
# 2016-03-12 | Montpellier - OGC Nice 0:2
# 2016-03-12 | Toulouse - Bordeaux 4:0
# 2016-03-12 | Bastia - Lille 1:2
# 2016-03-12 | Gazélec Ajaccio - Caen 1:0
# 2016-03-12 | Lorient - Marseille 1:1
# 2016-03-12 | Guingamp - Saint-Étienne 2:0
# 2016-03-13 | Troyes - Paris Saint-Germain 0:9
# 2016-03-13 | Rennes - Lyon 2:2
# 2016-03-13 | Nantes - Angers 2:0
# 2016-03-18 | Marseille - Rennes 2:5
# 2016-03-19 | Stade de Reims - Guingamp 0:1
# 2016-03-19 | Saint-Étienne - Montpellier 3:0
# 2016-03-19 | Caen - Troyes 2:1
# 2016-03-19 | Lille - Toulouse 1:0
# 2016-03-19 | Angers - Lorient 5:1
# 2016-03-19 | Lyon - Nantes 2:0
# 2016-03-20 | Paris Saint-Germain - AS Monaco 0:2
# 2016-03-20 | Bordeaux - Bastia 1:1
# 2016-03-20 | OGC Nice - Gazélec Ajaccio 3:0
# 2016-04-01 | AS Monaco - Bordeaux 1:2
# 2016-04-02 | Rennes - Stade de Reims 3:1
# 2016-04-02 | Gazélec Ajaccio - Saint-Étienne 0:2
# 2016-04-02 | Paris Saint-Germain - OGC Nice 4:1
# 2016-04-02 | Guingamp - Montpellier 2:2
# 2016-04-02 | Troyes - Angers 0:1
# 2016-04-02 | Toulouse - Caen 2:0
# 2016-04-03 | Bastia - Marseille 2:1
# 2016-04-03 | Lorient - Lyon 1:3
# 2016-04-03 | Nantes - Lille 0:3
# 2016-04-08 | Montpellier - Lyon 0:2
# 2016-04-09 | Saint-Étienne - Troyes 1:0
# 2016-04-09 | Caen - Lorient 1:2
# 2016-04-09 | Toulouse - Bastia 4:0
# 2016-04-09 | Stade de Reims - Nantes 2:1
# 2016-04-09 | Guingamp - Paris Saint-Germain 0:2
# 2016-04-09 | Angers - Gazélec Ajaccio 0:0
# 2016-04-10 | Marseille - Bordeaux 0:0
# 2016-04-10 | Lille - AS Monaco 4:1
# 2016-04-10 | OGC Nice - Rennes 3:0
# 2016-04-15 | Lyon - OGC Nice 1:1
# 2016-04-16 | Bastia - Saint-Étienne 0:1
# 2016-04-16 | Lorient - Toulouse 1:1
# 2016-04-16 | Bordeaux - Angers 1:3
# 2016-04-16 | Troyes - Stade de Reims 2:1
# ...
# 2023-02-04 | Paris Saint-Germain - Toulouse 2:1
# 2023-02-19 | Paris Saint-Germain - Lille 4:3
# 2023-02-26 | Marseille - Paris Saint-Germain 0:3
# 2023-03-04 | Paris Saint-Germain - Nantes 4:2
# 2023-03-11 | Stade Brestois - Paris Saint-Germain 1:2
# 2023-03-19 | Paris Saint-Germain - Rennes 0:2
# 2023-04-02 | Paris Saint-Germain - Lyon 0:1
# 2023-04-08 | OGC Nice - Paris Saint-Germain 0:2
# 2023-04-15 | Paris Saint-Germain - Lens 3:1
# 2023-04-21 | Angers - Paris Saint-Germain 1:2
# 2023-04-30 | Paris Saint-Germain - Lorient 1:3
# 2023-05-13 | Paris Saint-Germain - AC Ajaccio 5:0
# 2023-05-21 | Auxerre - Paris Saint-Germain 1:2
# 2023-05-27 | Strasbourg - Paris Saint-Germain 1:1
# 2023-06-03 | Paris Saint-Germain - Clermont Foot 2:3
#
# Total matches for this competition: 32
# ========================================
# 2022 | FIFA World Cup (2022)
#
# 2022-11-20 | Qatar - Ecuador 0:2
# 2022-11-21 | England - Iran 6:2
# 2022-11-21 | Senegal - Netherlands 0:2
# 2022-11-21 | United States - Wales 1:1
# 2022-11-22 | Denmark - Tunisia 0:0
# 2022-11-22 | Mexico - Poland 0:0
# 2022-11-22 | Argentina - Saudi Arabia 1:2
# 2022-11-22 | France - Australia 4:1
# 2022-11-23 | Belgium - Canada 1:0
# 2022-11-23 | Spain - Costa Rica 7:0
# 2022-11-23 | Germany - Japan 1:2
# 2022-11-23 | Morocco - Croatia 0:0
# 2022-11-24 | Switzerland - Cameroon 1:0
# 2022-11-24 | Portugal - Ghana 3:2
# 2022-11-24 | Uruguay - South Korea 0:0
# 2022-11-24 | Brazil - Serbia 2:0
# 2022-11-25 | Qatar - Senegal 1:3
# 2022-11-25 | England - United States 0:0
# 2022-11-25 | Wales - Iran 0:2
# 2022-11-25 | Netherlands - Ecuador 1:1
# 2022-11-26 | Argentina - Mexico 2:0
# 2022-11-26 | France - Denmark 2:1
# 2022-11-26 | Tunisia - Australia 0:1
# 2022-11-26 | Poland - Saudi Arabia 2:0
# 2022-11-27 | Croatia - Canada 4:1
# 2022-11-27 | Belgium - Morocco 0:2
# 2022-11-27 | Spain - Germany 1:1
# 2022-11-27 | Japan - Costa Rica 0:1
# 2022-11-28 | Portugal - Uruguay 2:0
# 2022-11-28 | Cameroon - Serbia 3:3
# 2022-11-28 | South Korea - Ghana 2:3
# 2022-11-28 | Brazil - Switzerland 1:0
# 2022-11-29 | Iran - United States 0:1
# 2022-11-29 | Ecuador - Senegal 1:2
# 2022-11-29 | Netherlands - Qatar 2:0
# 2022-11-29 | Wales - England 0:3
# 2022-11-30 | Tunisia - France 1:0
# 2022-11-30 | Saudi Arabia - Mexico 1:2
# 2022-11-30 | Poland - Argentina 0:2
# 2022-11-30 | Australia - Denmark 1:0
# 2022-12-01 | Japan - Spain 2:1
# 2022-12-01 | Croatia - Belgium 0:0
# 2022-12-01 | Costa Rica - Germany 2:4
# 2022-12-01 | Canada - Morocco 1:2
# 2022-12-02 | South Korea - Portugal 2:1
# 2022-12-02 | Cameroon - Brazil 1:0
# 2022-12-02 | Serbia - Switzerland 2:3
# 2022-12-02 | Ghana - Uruguay 0:2
# 2022-12-03 | Argentina - Australia 2:1
# 2022-12-03 | Netherlands - United States 3:1
# 2022-12-04 | England - Senegal 3:0
# 2022-12-04 | France - Poland 3:1
# 2022-12-05 | Brazil - South Korea 4:1
# 2022-12-05 | Japan - Croatia 1:1
# 2022-12-06 | Morocco - Spain 0:0
# 2022-12-06 | Portugal - Switzerland 6:1
# 2022-12-09 | Netherlands - Argentina 2:2
# 2022-12-09 | Croatia - Brazil 1:1
# 2022-12-10 | England - France 1:2
# 2022-12-10 | Morocco - Portugal 1:0
# 2022-12-13 | Argentina - Croatia 3:0
# 2022-12-14 | France - Morocco 2:0
# 2022-12-17 | Croatia - Morocco 2:1
# 2022-12-18 | Argentina - France 3:3
#
# Total matches for this competition: 64
# ========================================
# 2022 | UEFA Women's Euro (2022)
#
# 2022-07-06 | England Women's - Austria Women's 1:0
# 2022-07-07 | Norway Women's - Northern Ireland 4:1
# 2022-07-08 | Germany Women's - Denmark Women's 4:0
# 2022-07-08 | Spain Women's - WNT Finland 4:1
# 2022-07-09 | Netherlands Women's - Sweden Women's 1:1
# 2022-07-09 | Portugal Women's - Switzerland Women's 2:2
# 2022-07-10 | Belgium Women's - Iceland Women's 1:1
# 2022-07-10 | France Women's - Italy Women's 5:1
# 2022-07-11 | Austria Women's - Northern Ireland 2:0
# 2022-07-11 | England Women's - Norway Women's 8:0
# 2022-07-12 | Denmark Women's - WNT Finland 1:0
# 2022-07-12 | Germany Women's - Spain Women's 2:0
# 2022-07-13 | Netherlands Women's - Portugal Women's 3:2
# 2022-07-13 | Sweden Women's - Switzerland Women's 2:1
# 2022-07-14 | France Women's - Belgium Women's 2:1
# 2022-07-14 | Italy Women's - Iceland Women's 1:1
# 2022-07-15 | Austria Women's - Norway Women's 1:0
# 2022-07-15 | Northern Ireland - England Women's 0:5
# 2022-07-16 | Denmark Women's - Spain Women's 0:1
# 2022-07-16 | WNT Finland - Germany Women's 0:3
# 2022-07-17 | Sweden Women's - Portugal Women's 5:0
# 2022-07-17 | Switzerland Women's - Netherlands Women's 1:4
# 2022-07-18 | Iceland Women's - France Women's 1:1
# 2022-07-18 | Italy Women's - Belgium Women's 0:1
# 2022-07-20 | England Women's - Spain Women's 2:1
# 2022-07-21 | Germany Women's - Austria Women's 2:0
# 2022-07-22 | Sweden Women's - Belgium Women's 1:0
# 2022-07-23 | France Women's - Netherlands Women's 1:0
# 2022-07-26 | England Women's - Sweden Women's 4:0
# 2022-07-27 | Germany Women's - France Women's 2:1
# 2022-07-31 | England Women's - Germany Women's 2:1
#
# Total matches for this competition: 31
# ========================================
# 2023 | Major League Soccer (2023)
#
# 2023-08-27 | New York Red Bulls - Inter Miami 0:2
# 2023-08-31 | Inter Miami - Nashville SC 0:0
# 2023-09-04 | LAFC - Inter Miami 1:3
# 2023-09-21 | Inter Miami - Toronto FC 4:0
# 2023-10-08 | Inter Miami - Cincinnati 0:1
# 2023-10-22 | Charlotte - Inter Miami 1:0
#
# Total matches for this competition: 6
# ========================================
# 2023 | Women's World Cup (2023)
#
# 2023-07-20 | New Zealand Women's - Norway Women's 1:0
# 2023-07-20 | Australia Women's - Republic of Ireland Women's 1:0
# 2023-07-21 | Philippines Women's - Switzerland Women's 0:2
# 2023-07-21 | Spain Women's - Costa Rica Women's 3:0
# 2023-07-21 | Nigeria Women's - Canada Women's 0:0
# 2023-07-22 | England Women's - Haiti Women's 1:0
# 2023-07-22 | United States Women's - Vietnam Women's 3:0
# 2023-07-22 | Zambia Women's - Japan Women's 0:5
# 2023-07-22 | Denmark Women's - China PR Women's 1:0
# 2023-07-23 | Netherlands Women's - Portugal Women's 1:0
# 2023-07-23 | Sweden Women's - South Africa Women's 2:1
# 2023-07-23 | France Women's - Jamaica Women's 0:0
# 2023-07-24 | Brazil Women's - Panama Women's 4:0
# 2023-07-24 | Italy Women's - Argentina Women's 1:0
# 2023-07-24 | Germany Women's - Morocco Women's 6:0
# 2023-07-25 | Colombia Women's - Korea Republic Women's 2:0
# 2023-07-25 | New Zealand Women's - Philippines Women's 0:1
# 2023-07-25 | Switzerland Women's - Norway Women's 0:0
# 2023-07-26 | Japan Women's - Costa Rica Women's 2:0
# 2023-07-26 | Canada Women's - Republic of Ireland Women's 2:1
# 2023-07-26 | Spain Women's - Zambia Women's 5:0
# 2023-07-27 | United States Women's - Netherlands Women's 1:1
# 2023-07-27 | Portugal Women's - Vietnam Women's 2:0
# 2023-07-27 | Australia Women's - Nigeria Women's 2:3
# 2023-07-28 | England Women's - Denmark Women's 1:0
# 2023-07-28 | Argentina Women's - South Africa Women's 2:2
# 2023-07-28 | China PR Women's - Haiti Women's 1:0
# 2023-07-29 | Sweden Women's - Italy Women's 5:0
# 2023-07-29 | Panama Women's - Jamaica Women's 0:1
# 2023-07-29 | France Women's - Brazil Women's 2:1
# 2023-07-30 | Korea Republic Women's - Morocco Women's 0:1
# 2023-07-30 | Norway Women's - Philippines Women's 6:0
# 2023-07-30 | Germany Women's - Colombia Women's 1:2
# 2023-07-30 | Switzerland Women's - New Zealand Women's 0:0
# 2023-07-31 | Japan Women's - Spain Women's 4:0
# 2023-07-31 | Costa Rica Women's - Zambia Women's 1:3
# 2023-07-31 | Canada Women's - Australia Women's 0:4
# 2023-07-31 | Republic of Ireland Women's - Nigeria Women's 0:0
# 2023-08-01 | Portugal Women's - United States Women's 0:0
# 2023-08-01 | Haiti Women's - Denmark Women's 0:2
# 2023-08-01 | Vietnam Women's - Netherlands Women's 0:7
# 2023-08-01 | China PR Women's - England Women's 1:6
# 2023-08-02 | Argentina Women's - Sweden Women's 0:2
# 2023-08-02 | Jamaica Women's - Brazil Women's 0:0
# 2023-08-02 | South Africa Women's - Italy Women's 3:2
# 2023-08-02 | Panama Women's - France Women's 3:6
# 2023-08-03 | Korea Republic Women's - Germany Women's 1:1
# 2023-08-03 | Morocco Women's - Colombia Women's 1:0
# 2023-08-05 | Japan Women's - Norway Women's 3:1
# 2023-08-05 | Switzerland Women's - Spain Women's 1:5
# 2023-08-06 | Netherlands Women's - South Africa Women's 2:0
# 2023-08-06 | Sweden Women's - United States Women's 0:0
# 2023-08-07 | England Women's - Nigeria Women's 0:0
# 2023-08-07 | Australia Women's - Denmark Women's 2:0
# 2023-08-08 | France Women's - Morocco Women's 4:0
# 2023-08-08 | Colombia Women's - Jamaica Women's 1:0
# 2023-08-11 | Spain Women's - Netherlands Women's 2:1
# 2023-08-11 | Japan Women's - Sweden Women's 1:2
# 2023-08-12 | Australia Women's - France Women's 0:0
# 2023-08-12 | England Women's - Colombia Women's 2:1
# 2023-08-15 | Spain Women's - Sweden Women's 2:1
# 2023-08-16 | Australia Women's - England Women's 1:3
# 2023-08-19 | Sweden Women's - Australia Women's 2:0
# 2023-08-20 | Spain Women's - England Women's 1:0
#
# Total matches for this competition: 64
# ========================================
# 2023 | African Cup of Nations (2023)
#
# 2024-01-13 | Côte d'Ivoire - Guinea-Bissau 2:0
# 2024-01-14 | Egypt - Mozambique 2:2
# 2024-01-14 | Ghana - Cape Verde Islands 1:2
# 2024-01-14 | Nigeria - Equatorial Guinea 1:1
# 2024-01-15 | Senegal - Gambia 3:0
# 2024-01-15 | Algeria - Angola 1:1
# 2024-01-15 | Cameroon - Guinea 1:1
# 2024-01-16 | Burkina Faso - Mauritania 1:0
# 2024-01-16 | Tunisia - Namibia 0:1
# 2024-01-16 | Mali - South Africa 2:0
# 2024-01-17 | Morocco - Tanzania 3:0
# 2024-01-17 | Congo DR - Zambia 1:1
# 2024-01-18 | Egypt - Ghana 2:2
# 2024-01-18 | Côte d'Ivoire - Nigeria 0:1
# 2024-01-18 | Equatorial Guinea - Guinea-Bissau 4:2
# 2024-01-19 | Cape Verde Islands - Mozambique 3:0
# 2024-01-19 | Senegal - Cameroon 3:1
# 2024-01-19 | Guinea - Gambia 1:0
# 2024-01-20 | Algeria - Burkina Faso 2:2
# 2024-01-20 | Mauritania - Angola 2:3
# 2024-01-20 | Tunisia - Mali 1:1
# 2024-01-21 | Morocco - Congo DR 1:1
# 2024-01-21 | Zambia - Tanzania 1:1
# 2024-01-21 | South Africa - Namibia 4:0
# 2024-01-22 | Equatorial Guinea - Côte d'Ivoire 4:0
# 2024-01-22 | Guinea-Bissau - Nigeria 0:1
# 2024-01-22 | Mozambique - Ghana 2:2
# 2024-01-22 | Cape Verde Islands - Egypt 2:2
# 2024-01-23 | Angola - Burkina Faso 2:0
# 2024-01-23 | Gambia - Cameroon 2:3
# 2024-01-23 | Mauritania - Algeria 1:0
# 2024-01-23 | Guinea - Senegal 0:2
# 2024-01-24 | South Africa - Tunisia 0:0
# 2024-01-24 | Namibia - Mali 0:0
# 2024-01-24 | Tanzania - Congo DR 0:0
# 2024-01-24 | Zambia - Morocco 0:1
# 2024-01-27 | Nigeria - Cameroon 2:0
# 2024-01-27 | Angola - Namibia 3:0
# 2024-01-28 | Egypt - Congo DR 1:1
# 2024-01-28 | Equatorial Guinea - Guinea 0:1
# 2024-01-29 | Cape Verde Islands - Mauritania 1:0
# 2024-01-29 | Senegal - Côte d'Ivoire 1:1
# 2024-01-30 | Morocco - South Africa 0:2
# 2024-01-30 | Mali - Burkina Faso 2:1
# 2024-02-02 | Nigeria - Angola 1:0
# 2024-02-02 | Congo DR - Guinea 3:1
# 2024-02-03 | Cape Verde Islands - South Africa 0:0
# 2024-02-03 | Mali - Côte d'Ivoire 1:2
# 2024-02-07 | Nigeria - South Africa 1:1
# 2024-02-07 | Côte d'Ivoire - Congo DR 1:0
# 2024-02-10 | South Africa - Congo DR 0:0
# 2024-02-11 | Nigeria - Côte d'Ivoire 1:2
#
# Total matches for this competition: 52
# ========================================
# 2023 | 1. Bundesliga (2023/2024)
#
# 2023-08-19 | Bayer Leverkusen - RB Leipzig 3:2
# 2023-08-26 | Borussia Mönchengladbach - Bayer Leverkusen 0:3
# 2023-09-02 | Bayer Leverkusen - Darmstadt 98 5:1
# 2023-09-15 | Bayern Munich - Bayer Leverkusen 2:2
# 2023-09-24 | Bayer Leverkusen - FC Heidenheim 4:1
# 2023-09-30 | FSV Mainz 05 - Bayer Leverkusen 0:3
# 2023-10-08 | Bayer Leverkusen - FC Köln 3:0
# 2023-10-21 | Wolfsburg - Bayer Leverkusen 1:2
# 2023-10-29 | Bayer Leverkusen - Freiburg 2:1
# 2023-11-04 | Hoffenheim - Bayer Leverkusen 2:3
# 2023-11-12 | Bayer Leverkusen - Union Berlin 4:0
# 2023-11-25 | Werder Bremen - Bayer Leverkusen 0:3
# 2023-12-03 | Bayer Leverkusen - Borussia Dortmund 1:1
# 2023-12-10 | VfB Stuttgart - Bayer Leverkusen 1:1
# 2023-12-17 | Bayer Leverkusen - Eintracht Frankfurt 3:0
# 2023-12-20 | Bayer Leverkusen - Bochum 4:0
# 2024-01-13 | Augsburg - Bayer Leverkusen 0:1
# 2024-01-20 | RB Leipzig - Bayer Leverkusen 2:3
# 2024-01-27 | Bayer Leverkusen - Borussia Mönchengladbach 0:0
# 2024-02-03 | Darmstadt 98 - Bayer Leverkusen 0:2
# 2024-02-10 | Bayer Leverkusen - Bayern Munich 3:0
# 2024-02-17 | FC Heidenheim - Bayer Leverkusen 1:2
# 2024-02-23 | Bayer Leverkusen - FSV Mainz 05 2:1
# 2024-03-03 | FC Köln - Bayer Leverkusen 0:2
# 2024-03-10 | Bayer Leverkusen - Wolfsburg 2:0
# 2024-03-17 | Freiburg - Bayer Leverkusen 2:3
# 2024-03-30 | Bayer Leverkusen - Hoffenheim 2:1
# 2024-04-06 | Union Berlin - Bayer Leverkusen 0:1
# 2024-04-14 | Bayer Leverkusen - Werder Bremen 5:0
# 2024-04-21 | Borussia Dortmund - Bayer Leverkusen 1:1
# 2024-04-27 | Bayer Leverkusen - VfB Stuttgart 2:2
# 2024-05-05 | Eintracht Frankfurt - Bayer Leverkusen 1:5
# 2024-05-12 | Bochum - Bayer Leverkusen 0:5
# 2024-05-18 | Bayer Leverkusen - Augsburg 2:1
#
# Total matches for this competition: 34
# ========================================
# 2024 | Copa America (2024)
#
# 2024-06-21 | Argentina - Canada 2:0
# 2024-06-22 | Peru - Chile 0:0
# 2024-06-23 | Mexico - Jamaica 1:0
# 2024-06-23 | Ecuador - Venezuela 1:2
# 2024-06-24 | United States - Bolivia 2:0
# 2024-06-24 | Uruguay - Panama 3:1
# 2024-06-25 | Colombia - Paraguay 2:1
# 2024-06-25 | Brazil - Costa Rica 0:0
# 2024-06-26 | Peru - Canada 0:1
# 2024-06-26 | Chile - Argentina 0:1
# 2024-06-27 | Venezuela - Mexico 1:0
# 2024-06-27 | Ecuador - Jamaica 3:1
# 2024-06-28 | Panama - United States 2:1
# 2024-06-28 | Uruguay - Bolivia 5:0
# 2024-06-29 | Colombia - Costa Rica 3:0
# 2024-06-29 | Paraguay - Brazil 1:4
# 2024-06-30 | Canada - Chile 0:0
# 2024-06-30 | Argentina - Peru 2:0
# 2024-07-01 | Jamaica - Venezuela 0:3
# 2024-07-01 | Mexico - Ecuador 0:0
# 2024-07-02 | United States - Uruguay 0:1
# 2024-07-02 | Bolivia - Panama 1:3
# 2024-07-03 | Brazil - Colombia 1:1
# 2024-07-03 | Costa Rica - Paraguay 2:1
# 2024-07-05 | Argentina - Ecuador 1:1
# 2024-07-06 | Venezuela - Canada 1:1
# 2024-07-07 | Uruguay - Brazil 0:0
# 2024-07-07 | Colombia - Panama 5:0
# 2024-07-10 | Argentina - Canada 2:0
# 2024-07-11 | Uruguay - Colombia 0:1
# 2024-07-14 | Canada - Uruguay 2:2
# 2024-07-15 | Argentina - Colombia 1:0
#
# Total matches for this competition: 32
# ========================================
# 2024 | UEFA Euro (2024)
#
# 2024-06-14 | Germany - Scotland 5:1
# 2024-06-15 | Spain - Croatia 3:0
# 2024-06-15 | Italy - Albania 2:1
# 2024-06-15 | Hungary - Switzerland 1:3
# 2024-06-16 | Slovenia - Denmark 1:1
# 2024-06-16 | Serbia - England 0:1
# 2024-06-16 | Poland - Netherlands 1:2
# 2024-06-17 | Romania - Ukraine 3:0
# 2024-06-17 | Belgium - Slovakia 0:1
# 2024-06-17 | Austria - France 0:1
# 2024-06-18 | Portugal - Czech Republic 2:1
# 2024-06-18 | Turkey - Georgia 3:1
# 2024-06-19 | Scotland - Switzerland 1:1
# 2024-06-19 | Croatia - Albania 2:2
# 2024-06-19 | Germany - Hungary 2:0
# 2024-06-20 | Slovenia - Serbia 1:1
# 2024-06-20 | Denmark - England 1:1
# 2024-06-20 | Spain - Italy 1:0
# 2024-06-21 | Slovakia - Ukraine 1:2
# 2024-06-21 | Poland - Austria 1:3
# 2024-06-21 | Netherlands - France 0:0
# 2024-06-22 | Georgia - Czech Republic 1:1
# 2024-06-22 | Belgium - Romania 2:0
# 2024-06-22 | Turkey - Portugal 0:3
# 2024-06-23 | Switzerland - Germany 1:1
# 2024-06-23 | Scotland - Hungary 0:1
# 2024-06-24 | Croatia - Italy 1:1
# 2024-06-24 | Albania - Spain 0:1
# 2024-06-25 | Netherlands - Austria 2:3
# 2024-06-25 | England - Slovenia 0:0
# 2024-06-25 | Denmark - Serbia 0:0
# 2024-06-25 | France - Poland 1:1
# 2024-06-26 | Czech Republic - Turkey 1:2
# 2024-06-26 | Ukraine - Belgium 0:0
# 2024-06-26 | Georgia - Portugal 2:0
# 2024-06-26 | Slovakia - Romania 1:1
# 2024-06-29 | Switzerland - Italy 2:0
# 2024-06-29 | Germany - Denmark 2:0
# 2024-06-30 | Spain - Georgia 4:1
# 2024-06-30 | England - Slovakia 2:1
# 2024-07-01 | Portugal - Slovenia 0:0
# 2024-07-01 | France - Belgium 1:0
# 2024-07-02 | Austria - Turkey 1:2
# 2024-07-02 | Romania - Netherlands 0:3
# 2024-07-05 | Spain - Germany 2:1
# 2024-07-05 | Portugal - France 0:0
# 2024-07-06 | England - Switzerland 1:1
# 2024-07-06 | Netherlands - Turkey 2:1
# 2024-07-09 | Spain - France 2:1
# 2024-07-10 | Netherlands - England 1:2
# 2024-07-14 | Spain - England 2:1
#
# Total matches for this competition: 51
#
# -------------------------------------------
# Grand total across all comps/seasons: 3433 matches

# %%
all_matches
# Out:
#       match_id  match_date      kick_off                     competition
# 0      3888704  1958-06-24  21:00:00.000  International - FIFA World Cup  \
# 1      3888705  1958-06-29  17:00:00.000  International - FIFA World Cup
# 2      3888854  1962-05-30  21:00:00.000  International - FIFA World Cup
# 3      3888699  1970-06-04  01:00:00.000  International - FIFA World Cup
# 4      3888700  1970-06-07  21:00:00.000  International - FIFA World Cup
# ...        ...         ...           ...                             ...
# 3428   3942227  2024-07-06  19:00:00.000              Europe - UEFA Euro
# 3429   3942382  2024-07-06  22:00:00.000              Europe - UEFA Euro
# 3430   3942752  2024-07-09  22:00:00.000              Europe - UEFA Euro
# 3431   3942819  2024-07-10  22:00:00.000              Europe - UEFA Euro
# 3432   3943043  2024-07-14  22:00:00.000              Europe - UEFA Euro
#
#      season    home_team       away_team  home_score  away_score match_status
# 0      1958       Brazil          France           5           2    available  \
# 1      1958       Brazil          Sweden           5           2    available
# 2      1962       Brazil          Mexico           2           0    available
# 3      1970       Brazil  Czechoslovakia           4           1    available
# 4      1970       Brazil         England           1           0    available
# ...     ...          ...             ...         ...         ...          ...
# 3428   2024      England     Switzerland           1           1    available
# 3429   2024  Netherlands          Turkey           2           1    available
# 3430   2024        Spain          France           2           1    available
# 3431   2024  Netherlands         England           1           2    available
# 3432   2024        Spain         England           2           1    available
#
#       ...            last_updated_360 match_week competition_stage
# 0     ...                        None          6       Semi-finals  \
# 1     ...                        None          7             Final
# 2     ...                        None          1       Group Stage
# 3     ...                        None          1       Group Stage
# 4     ...                        None          2       Group Stage
# ...   ...                         ...        ...               ...
# 3428  ...  2024-07-14T15:57:51.414762          5    Quarter-finals
# 3429  ...  2024-07-10T06:56:35.146850          5    Quarter-finals
# 3430  ...  2024-07-10T13:01:26.597509          6       Semi-finals
# 3431  ...  2024-07-15T07:57:36.684453          6       Semi-finals
# 3432  ...  2024-07-15T15:52:24.778809          7             Final
#
#                     stadium                     referee
# 0             Friends Arena            Mervyn Griffiths  \
# 1             Friends Arena              Maurice Guigue
# 2        Estadio Sausalito                          NaN
# 3           Estadio Jalisco  Ramón Ivanoes Barreto Ruiz
# 4           Estadio Jalisco               Abraham Klein
# ...                     ...                         ...
# 3428     Merkur Spiel-Arena              Daniele Orsato
# 3429  Olympiastadion Berlin              Clément Turpin
# 3430          Allianz Arena               Slavko Vinčić
# 3431      Signal-Iduna-Park                Felix Zwayer
# 3432  Olympiastadion Berlin           François Letexier
#
#                    home_managers         away_managers data_version
# 0            Vicente Ítalo Feola        Albert Batteux        1.1.0  \
# 1            Vicente Ítalo Feola         George Raynor        1.1.0
# 2                 Aymoré Moreira       Ignacio Trelles        1.1.0
# 3       Mário Jorge Lobo Zagallo           Jozef Marko        1.1.0
# 4       Mário Jorge Lobo Zagallo  Alfred Ernest Ramsey        1.1.0
# ...                          ...                   ...          ...
# 3428            Gareth Southgate           Murat Yakin        1.1.0
# 3429               Ronald Koeman     Vincenzo Montella        1.1.0
# 3430  Luis de la Fuente Castillo      Didier Deschamps        1.1.0
# 3431               Ronald Koeman      Gareth Southgate        1.1.0
# 3432  Luis de la Fuente Castillo      Gareth Southgate        1.1.0
#
#      shot_fidelity_version xy_fidelity_version
# 0                        2                   2
# 1                        2                   2
# 2                        2                   2
# 3                        2                   2
# 4                        2                   2
# ...                    ...                 ...
# 3428                     2                   2
# 3429                     2                   2
# 3430                     2                   2
# 3431                     2                   2
# 3432                     2                   2
#
# [3433 rows x 22 columns]

# %% [markdown]
# # Step 3: Load Matches for a Specific Competition

# %% [markdown]
# Let's select a specific competition (e.g., La Liga 2020/21) and retrieve all the matches from that season. This is useful to explore match details, including:
#
# - Match ID (needed to extract events later)
# - Teams playing (home and away)
# - Date of the match

# %%
# Select a competition (e.g., La Liga 2020/21)
competition_id = 11  # La Liga
season_id = 90       # 2020/21 season

# Load matches for the selected competition
matches = sb.matches(competition_id=competition_id, season_id=season_id)

# Display useful match information
print(f"Matches for La Liga 2020/21 (Competition ID: {competition_id}, Season ID: {season_id})\n")

# Print formatted match list
for _, row in matches.iterrows():
    print(f"{row['match_date']} | {row['home_team']} vs {row['away_team']}")
# Out:
# Matches for La Liga 2020/21 (Competition ID: 11, Season ID: 90)
#
# 2020-10-31 | Deportivo Alavés vs Barcelona
# 2021-01-09 | Granada vs Barcelona
# 2021-05-16 | Barcelona vs Celta Vigo
# 2021-02-07 | Real Betis vs Barcelona
# 2021-03-06 | Osasuna vs Barcelona
# 2021-04-10 | Real Madrid vs Barcelona
# 2020-12-13 | Barcelona vs Levante UD
# 2020-09-27 | Barcelona vs Villarreal
# 2020-10-01 | Celta Vigo vs Barcelona
# 2020-10-24 | Barcelona vs Real Madrid
# 2021-01-03 | Huesca vs Barcelona
# 2020-10-04 | Barcelona vs Sevilla
# 2020-10-17 | Getafe vs Barcelona
# 2020-11-21 | Atlético Madrid vs Barcelona
# 2020-12-19 | Barcelona vs Valencia
# 2021-04-29 | Barcelona vs Granada
# 2021-05-08 | Barcelona vs Atlético Madrid
# 2021-05-11 | Levante UD vs Barcelona
# 2021-05-02 | Valencia vs Barcelona
# 2021-03-15 | Barcelona vs Huesca
# 2021-04-22 | Barcelona vs Getafe
# 2021-03-21 | Real Sociedad vs Barcelona
# 2020-12-16 | Barcelona vs Real Sociedad
# 2020-12-22 | Real Valladolid vs Barcelona
# 2020-12-05 | Cádiz vs Barcelona
# 2021-01-06 | Athletic Club vs Barcelona
# 2021-02-13 | Barcelona vs Deportivo Alavés
# 2021-04-05 | Barcelona vs Real Valladolid
# 2021-02-27 | Sevilla vs Barcelona
# 2021-01-31 | Barcelona vs Athletic Club
# 2020-11-29 | Barcelona vs Osasuna
# 2021-02-21 | Barcelona vs Cádiz
# 2021-02-24 | Barcelona vs Elche
# 2021-04-25 | Villarreal vs Barcelona
# 2020-11-07 | Barcelona vs Real Betis

# %% [markdown]
# # Step 4: Select a Specific Match and Load Event Data

# %% [markdown]
# Let's select a specific game and load the data of that event. For example, let's find both matches between Barcelona and Real Madrid in La Liga 2020/21, also known as El Clásico.
#
# We will display both:
#
# - First Leg: First match of the season between the two teams.
# - Second Leg: Return match later in the season.

# %%
# Filter for Barcelona vs Real Madrid (both home & away games)
clasico_matches = matches[
    ((matches["home_team"] == "Barcelona") & (matches["away_team"] == "Real Madrid")) |
    ((matches["home_team"] == "Real Madrid") & (matches["away_team"] == "Barcelona"))
]

# Ensure that two matches are found
if clasico_matches.shape[0] < 2:
    print("Not enough matches found for Barcelona vs Real Madrid in this dataset.")
else:
    # Sort matches by date 
    clasico_matches = clasico_matches.sort_values(by="match_date")

    # First match
    match_id_1 = clasico_matches.iloc[0]["match_id"]
    home_team_1 = clasico_matches.iloc[0]["home_team"]
    away_team_1 = clasico_matches.iloc[0]["away_team"]
    match_date_1 = clasico_matches.iloc[0]["match_date"]
    home_score_1 = clasico_matches.iloc[0]["home_score"]
    away_score_1 = clasico_matches.iloc[0]["away_score"]

    # Second match
    match_id_2 = clasico_matches.iloc[1]["match_id"]
    home_team_2 = clasico_matches.iloc[1]["home_team"]
    away_team_2 = clasico_matches.iloc[1]["away_team"]
    match_date_2 = clasico_matches.iloc[1]["match_date"]
    home_score_2 = clasico_matches.iloc[1]["home_score"]
    away_score_2 = clasico_matches.iloc[1]["away_score"]

    # Print both matches
    print(f"El Clásico Matches in La Liga 2020/21:\n")
    print(f"[ID: {match_id_1}] {match_date_1} | {home_team_1} - {away_team_1} {home_score_1}:{away_score_1}")
    print(f"[ID: {match_id_2}] {match_date_2} | {home_team_2} - {away_team_2} {home_score_2}:{away_score_2}")
# Out:
# El Clásico Matches in La Liga 2020/21:
#
# [ID: 3773585] 2020-10-24 | Barcelona - Real Madrid 1:3
# [ID: 3773497] 2021-04-10 | Real Madrid - Barcelona 2:1

# %% [markdown]
# # Step 5: Analyze Team Shape and Average Player Positions

# %% [markdown]
# We will calculate and visualize:
#
# - The average position of each player during the match
# - How the team shape evolves by dividing the match into halves
# - Compare the positioning of both teams

# %%
# Load events for the first El Clásico match
events = sb.events(match_id=match_id_1) # you can also use match_id_2

# "Starting XI" rows for each team
home_team = events.loc[events['type'] == 'Starting XI', 'team'].unique()[0]
away_team = events.loc[events['type'] == 'Starting XI', 'team'].unique()[1]

print("Home Team:", home_team)
print("Away Team:", away_team)
# Out:
# Home Team: Barcelona
# Away Team: Real Madrid

# %%
# Extract the Starting XI for each team and build a map of player names to jersey numbers
def build_xi_jersey_map(events_df, team_name):
    """
    Returns a dict mapping:
       "Lionel Andrés Messi Cuccittini" -> 10,
       "Frenkie de Jong" -> 21, 
       etc...
    for that team's Starting XI.
    """
    row = events_df[
        (events_df['type'] == 'Starting XI') &
        (events_df['team'] == team_name)
    ].iloc[0]
    
    lineup = row['tactics']['lineup']
    
    jersey_map = {}
    for pl in lineup:
        player_dict = pl.get('player', {})
        full_name   = player_dict.get('name', "Unknown_Player")
        jersey_num  = pl.get('jersey_number', None)
        
        # e.g., "Lionel Andrés Messi Cuccittini": 10
        jersey_map[full_name] = jersey_num
    
    return jersey_map


home_jersey_map = build_xi_jersey_map(events, home_team)
away_jersey_map = build_xi_jersey_map(events, away_team)

print("Home XI jersey map:\n", home_jersey_map)
print("\nAway XI jersey map:\n", away_jersey_map)
# Out:
# Home XI jersey map:
#  {'Norberto Murara Neto': 13, 'Sergino Dest': 2, 'Gerard Piqué Bernabéu': 3, 'Clément Lenglet': 15, 'Jordi Alba Ramos': 18, 'Sergio Busquets i Burgos': 5, 'Frenkie de Jong': 21, 'Pedro González López': 16, 'Philippe Coutinho Correia': 14, 'Anssumane Fati': 22, 'Lionel Andrés Messi Cuccittini': 10}
#
# Away XI jersey map:
#  {'Thibaut Courtois': 1, 'José Ignacio Fernández Iglesias': 6, 'Raphaël Varane': 5, 'Sergio Ramos García': 4, 'Ferland Mendy': 23, 'Carlos Henrique Casimiro': 14, 'Federico Santiago Valverde Dipetta': 15, 'Toni Kroos': 8, 'Marco Asensio Willemsen': 11, 'Vinícius José Paixão de Oliveira Júnior': 20, 'Karim Benzema': 9}

# %%
# Filter events to only include the Starting XI players

all_starters = set(home_jersey_map.keys()).union(away_jersey_map.keys())

events_starters = events[events['player'].isin(all_starters)].copy()

def get_jersey_number(player_name):
    if player_name in home_jersey_map:
        return home_jersey_map[player_name]
    elif player_name in away_jersey_map:
        return away_jersey_map[player_name]
    else:
        return None

events_starters['jersey_number'] = events_starters['player'].apply(get_jersey_number)

print("Original events shape:", events.shape[0])
print("Filtered (starters only) shape:", events_starters.shape[0])
# Out:
# Original events shape: 4213
# Filtered (starters only) shape: 3924

# %%
# Compute average positions for each player

def compute_average_positions(df):
    """
    Group by (player, jersey_number), average their 'location'.
    Return columns: [player, jersey_number, x, y].
    """
    d = df.dropna(subset=['location']).copy()
    
    d['x'] = d['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
    d['y'] = d['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)
    
    avg_positions = (
        d.groupby(['player','jersey_number'], as_index=False)
         .agg({'x':'mean','y':'mean'})
    )
    return avg_positions

home_events = events_starters[events_starters['team'] == home_team]
away_events = events_starters[events_starters['team'] == away_team]

home_avg_positions = compute_average_positions(home_events)
away_avg_positions = compute_average_positions(away_events)

home_avg_positions
# Out:
#                             player  jersey_number          x          y
# 0                   Anssumane Fati             22  77.830275  39.996330
# 1                  Clément Lenglet             15  38.922051  22.309744
# 2                  Frenkie de Jong             21  62.520168  21.523109
# 3            Gerard Piqué Bernabéu              3  38.354167  49.375000
# 4                 Jordi Alba Ramos             18  69.016749  11.050739
# 5   Lionel Andrés Messi Cuccittini             10  74.355185  39.164815
# 6             Norberto Murara Neto             13   8.526415  39.360377
# 7             Pedro González López             16  68.355844  59.520130
# 8        Philippe Coutinho Correia             14  73.484810  25.563291
# 9                     Sergino Dest              2  62.950777  67.466321
# 10        Sergio Busquets i Burgos              5  62.073256  39.692248

# %% [markdown]
# Let's build a function that allows to draw a pitch in which it is possible to represent the positions of the players

# %%
def draw_pitch(ax=None, field_color='green'):
    """
    Draw a 120 x 80 pitch on the given Axes.
    (0,0) is top-left, (120,80) is bottom-right.
    """
    if ax is None:
        ax = plt.subplots(figsize=(12.0, 8.0))
    
    # Set pitch background
    if field_color == 'green':
        ax.set_facecolor('mediumseagreen')
        lc = 'whitesmoke'  # line color
        border_color = 'white'  # Border color to differentiate pitch edges
    else:
        lc = 'black'
        border_color = 'white'
    
    # Outer boundaries with distinct color
    ax.plot([0,0],[0,80], color=border_color, linewidth=3)
    ax.plot([120,120],[0,80], color=border_color, linewidth=3)
    ax.plot([0,120],[0,0], color=border_color, linewidth=3)
    ax.plot([0,120],[80,80], color=border_color, linewidth=3)
    
    # Center line
    ax.plot([60,60],[0,80], color=lc, linewidth=2)
    
    # Center circle
    center_circle = plt.Circle((60, 40), 10, color=lc, fill=False, linewidth=2)
    ax.add_patch(center_circle)


    
    # Penalty areas and arcs (both sides fixed)
    for x in [0, 120]:
        penalty_x = 18 if x == 0 else 120-18
        goal_x = 6 if x == 0 else 120-6
        penalty_spot = 11 if x == 0 else 109
        arc_center = (12, 40) if x == 0 else (108.2, 40)
        arc_angle = 0 if x == 0 else 180
        
        # Penalty area
        ax.plot([x, penalty_x], [18, 18], color=lc, linewidth=2)
        ax.plot([penalty_x, penalty_x], [18, 62], color=lc, linewidth=2)
        ax.plot([x, penalty_x], [62, 62], color=lc, linewidth=2)
        
        # Goal area
        ax.plot([x, goal_x], [30, 30], color=lc, linewidth=2)
        ax.plot([goal_x, goal_x], [30, 50], color=lc, linewidth=2)
        ax.plot([x, goal_x], [50, 50], color=lc, linewidth=2)
        
        # Penalty spots
        ax.plot([penalty_spot], [40], marker='o', markersize=5, color=lc)

        # Center spot
        ax.plot([60], [40], marker='o', markersize=5, color=lc)
        
        # Penalty arcs
        penalty_arc = Arc(
            arc_center, 20, 20, angle=arc_angle, 
            theta1=308, theta2=52, color=lc, linewidth=2
        )
        ax.add_patch(penalty_arc)
        
    # Corners
    corner_radius = 2

    ax.add_patch(plt.Circle((0, 0), corner_radius, color=lc, fill=False, linewidth=2))      # top-left
    ax.add_patch(plt.Circle((120, 0), corner_radius, color=lc, fill=False, linewidth=2))    # top-right
    ax.add_patch(plt.Circle((0, 80), corner_radius, color=lc, fill=False, linewidth=2))     # bottom-left
    ax.add_patch(plt.Circle((120, 80), corner_radius, color=lc, fill=False, linewidth=2))   # bottom-right

    
    # Flip y-axis so top=0
    ax.set_xlim(0,120)
    ax.set_ylim(80,0)
    
    # Remove ticks but maintain pitch edges visibility
    ax.set_xticks([])
    ax.set_yticks([])
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
    return ax

# %%
# Define a function to plot average positions
def plot_team_with_lineup(avg_positions_df, team_name, jersey_map):
    """
    Creates one figure with:
      - Top: a pitch, points for each player's avg x,y labeled by jersey only
      - Bottom: a textual listing of the lineup, # -> name
    """
    # We'll create a 2-row layout: top is pitch, bottom is text
    fig = plt.figure(figsize=(12,10))
    gs = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[4,1])
    
    # -- TOP: PITCH --
    ax_pitch = fig.add_subplot(gs[0,0])
    draw_pitch(ax=ax_pitch)
    ax_pitch.set_title(f"{team_name} - Average On-Ball Positions (Starters)", color="black", fontsize=14, fontweight='bold')
    
    # Plot the positions
    ax_pitch.scatter(avg_positions_df['x'], avg_positions_df['y'],
                     s=100, c='red', edgecolors='black', linewidths=1.0, zorder = 3)
    
    # Label each dot with the jersey number
    for _, row in avg_positions_df.iterrows():
        num_str = str(row['jersey_number'])
        ax_pitch.text(row['x'], row['y'] - 2, num_str,
                      color='white', ha='center', fontsize=9,
                      bbox=dict(boxstyle="round,pad=0.3", fc="black", alpha=0.7))

   # -- BOTTOM: LINEUP TEXT --
    ax_lineup = fig.add_subplot(gs[1, 0])
    ax_lineup.axis('off')  # Hide axis lines/ticks

    # Sort the dictionary by jersey number
    sorted_lineup = sorted(jersey_map.items(), key=lambda item: item[1])

    # We'll build a multiline string
    lines = []
    lines.append(f"{team_name} Starting XI:")
    lines.append("=" * 25)
    for full_name, number in sorted_lineup:
        # Format the jersey number into 2 chars wide, right-aligned
        # Then append " - <full_name>"
        line_str = f"{number:2d} - {full_name}"
        lines.append(line_str)

    # Join them with newlines
    full_text = "\n".join(lines)

    # We can place the text with a white, semi‐transparent box behind it
    ax_lineup.text(
        0.02, 0.5, 
        full_text, 
        va='center', ha='left', fontsize=12,
        bbox=dict(boxstyle="round,pad=0.5", fc="white", alpha=0.4)
    )


    plt.tight_layout()
    plt.show()


# Plot for the home team
plot_team_with_lineup(home_avg_positions, home_team, home_jersey_map)

# Plot for the away team
plot_team_with_lineup(away_avg_positions, away_team, away_jersey_map)

# %% [markdown]
# ## Step 5.1: Latest Match

# %% [markdown]
# Let's follow the same instructions of the previous step to do the same for the latest match in the dataset

# %%
# Load the latest competition
comps = sb.competitions()

# Extract the numeric year from the 'season_name' (e.g. "2020/2021" -> "2020")
comps['season_year'] = comps['season_name'].str[:4].astype(int)

# Sort by year (descending) so the top row is the latest
comps_sorted = comps.sort_values(by='season_year', ascending=False).reset_index(drop=True)

# Pick the FIRST row in the sorted DF -> the LATEST competition
latest_comp_row = comps_sorted.iloc[0]
cid = latest_comp_row['competition_id']
sid = latest_comp_row['season_id']

print("Latest competition by year:", latest_comp_row['competition_name'] + " " + latest_comp_row['season_name'])
print("Year (Season):", latest_comp_row['season_name'])
print("competition_id =", cid)
print("season_id =", sid)
# Out:
# Latest competition by year: Copa America 2024
# Year (Season): 2024
# competition_id = 223
# season_id = 282

# %%
# Load matches for the latest competition
comp_matches = sb.matches(competition_id=cid, season_id=sid)

# Sort by match_date ascending
comp_matches = comp_matches.sort_values(by='match_date')

# Pick the final row => the most recent match date in that competition
last_match_id = comp_matches.iloc[-1]['match_id']
print("Most recent match_id in that competition:", last_match_id)
# Out:
# Most recent match_id in that competition: 3943077

# %%
# We'll assume you've already run:
# comp_matches = sb.matches(competition_id=cid, season_id=sid)
# comp_matches = comp_matches.sort_values(by='match_date')

# Pick the last row => the most recent match
latest_match = comp_matches.iloc[-1]

# Extract date, teams, and scores
match_date  = latest_match['match_date']
home_team   = latest_match['home_team']
away_team   = latest_match['away_team']
home_score  = latest_match['home_score']
away_score  = latest_match['away_score']

# Print a simple summary
print(f"[ID: {last_match_id}] 📅 {match_date} | ⚽ {home_team} - {away_team} {home_score}:{away_score}")
# Out:
# [ID: 3943077] 📅 2024-07-15 | ⚽ Argentina - Colombia 1:0

# %%
# Load events for the latest match
events_latest = sb.events(match_id=last_match_id)

# Extract the Starting XI for each team and build a map of player names to jersey numbers
home_jersey_map = build_xi_jersey_map(events_latest, home_team)
away_jersey_map = build_xi_jersey_map(events_latest, away_team)

# Filter for Starting XI players only
all_starters = set(home_jersey_map.keys()).union(away_jersey_map.keys())

# Filter events to only include the Starting XI players
events_latest_starters = events_latest[events_latest['player'].isin(all_starters)].copy()
    
# Add a new column for jersey number
events_latest_starters['jersey_number'] = events_latest_starters['player'].apply(get_jersey_number)

# Compute average positions for each player
home_events_latest = events_latest_starters[events_latest_starters['team'] == home_team]
away_events_latest = events_latest_starters[events_latest_starters['team'] == away_team]

home_avg_positions_latest = compute_average_positions(home_events_latest)
away_avg_positions_latest = compute_average_positions(away_events_latest)

# Plot for the home team
plot_team_with_lineup(home_avg_positions_latest, home_team, home_jersey_map)

# Plot for the away team
plot_team_with_lineup(away_avg_positions_latest, away_team, away_jersey_map)

# %% [markdown]
# # Step 5.2: First Match

# %% [markdown]
# Let's follow the same instructions of the previous step to do the same for the firstt match in the dataset

# %%
# Load the latest competition
comps = sb.competitions()

# Extract the numeric year from the 'season_name' (e.g. "2020/2021" -> "2020")
comps['season_year'] = comps['season_name'].str[:4].astype(int)

# Sort by year (ascending) so the top row is the older
comps_sorted = comps.sort_values(by='season_year', ascending=True).reset_index(drop=True)

# Pick the FIRST row in the sorted DF -> the OLDEST competition
latest_comp_row = comps_sorted.iloc[0]
cid = latest_comp_row['competition_id']
sid = latest_comp_row['season_id']

print("Latest competition by year:", latest_comp_row['competition_name'] + " " + latest_comp_row['season_name'])
print("Year (Season):", latest_comp_row['season_name'])
print("competition_id =", cid)
print("season_id =", sid)
# Out:
# Latest competition by year: FIFA World Cup 1958
# Year (Season): 1958
# competition_id = 43
# season_id = 269

# %%
# Load matches for the latest competition
comp_matches = sb.matches(competition_id=cid, season_id=sid)

# Sort by match_date ascending
comp_matches = comp_matches.sort_values(by='match_date')

# Pick the first row => the most recent match date in that competition
first_match_id = comp_matches.iloc[0]['match_id']
print("Most oldest match_id in that competition:", first_match_id)
# Out:
# Most oldest match_id in that competition: 3888704

# %%
# Pick the first row => the oldest match
oldest_match = comp_matches.iloc[0]

# Extract date, teams, and scores
match_date  = oldest_match['match_date']
home_team   = oldest_match['home_team']
away_team   = oldest_match['away_team']
home_score  = oldest_match['home_score']
away_score  = oldest_match['away_score']

# Print a simple summary
print(f"[ID: {first_match_id}] 📅 {match_date} | ⚽ {home_team} - {away_team} {home_score}:{away_score}")
# Out:
# [ID: 3888704] 📅 1958-06-24 | ⚽ Brazil - France 5:2

# %%
# Load events for the older match
events_older = sb.events(match_id=first_match_id)

# Extract the Starting XI for each team and build a map of player names to jersey numbers
home_jersey_map = build_xi_jersey_map(events_older, home_team)
away_jersey_map = build_xi_jersey_map(events_older, away_team)

# Filter for Starting XI players only
all_starters = set(home_jersey_map.keys()).union(away_jersey_map.keys())

# Filter events to only include the Starting XI players
events_older_starters = events_older[events_older['player'].isin(all_starters)].copy()
    
# Add a new column for jersey number
events_older_starters['jersey_number'] = events_older_starters['player'].apply(get_jersey_number)

# Compute average positions for each player
home_events_older = events_older_starters[events_older_starters['team'] == home_team]
away_events_older = events_older_starters[events_older_starters['team'] == away_team]

home_avg_positions_older= compute_average_positions(home_events_older)
away_avg_positions_older = compute_average_positions(away_events_older)

# Plot for the home team
plot_team_with_lineup(home_avg_positions_older, home_team, home_jersey_map)

# Plot for the away team
plot_team_with_lineup(away_avg_positions_older, away_team, away_jersey_map)

# %% [markdown]
# # Step 6: Match Events Analysis

# %% [markdown]
# ## Step 6.1: Choose the Match and Retrieve the Linked Events

# %% [markdown]
# Let's retrieve all matches for a specific competition (Uefa Euro) and season (2024) from the dataset, sorted by date. Then let's select the third match (index 2) in that list and prints some basic information about the chosen game. These details include the match ID, competition name, stage, date, home and away teams, final score, stadium, and referee from the "chosen_match" object

# %%
competition_id = 55   # e.g., Euro 2024
season_id = 282       # 2024
all_matches = sb.matches(competition_id=competition_id, season_id=season_id)

# Sort by date just to see them in order
all_matches = all_matches.sort_values(by='match_date')

# Let’s pick a game at random (e.g., the 3rd match)
match_pos = 2
chosen_match = all_matches.iloc[match_pos]
match_id = chosen_match['match_id']

# Print out some basic info
print("Chosen Match ID:", match_id)
print("Competition:", all_matches['competition'][match_pos])
print("Stage:", chosen_match['competition_stage'])
print("Date:", chosen_match['match_date'])
print("Teams:", chosen_match['home_team'], "vs.", chosen_match['away_team'])
print("Score:", chosen_match['home_score'], "-", chosen_match['away_score'])
print("Stadium:", chosen_match['stadium'])
print("Referee", chosen_match['referee'])
# Out:
# Chosen Match ID: 3930161
# Competition: Europe - UEFA Euro
# Stage: Group Stage
# Date: 2024-06-15
# Teams: Italy vs. Albania
# Score: 2 - 1
# Stadium: Signal-Iduna-Park
# Referee Felix Zwayer

# %% [markdown]
# The following cell uses the sb.events(...) function to retrieve all event data for the previously selected match and displays how many total events are in the dataset. It also shows the first rows, which provide a quick look at the structure of the event DataFrame. Each row represents a single on‐pitch action (e.g., pass, shot, foul) with various columns detailing the event’s type, location, timing, and associated players or teams.

# %%
# Load events for the chosen match
events = sb.events(match_id=match_id)

print("Number of events:", events.shape[0])

events.head(10)
# Out:
# Number of events: 4066
#   50_50 bad_behaviour_card ball_receipt_outcome block_deflection
# 0   NaN                NaN                  NaN              NaN  \
# 1   NaN                NaN                  NaN              NaN
# 2   NaN                NaN                  NaN              NaN
# 3   NaN                NaN                  NaN              NaN
# 4   NaN                NaN                  NaN              NaN
# 5   NaN                NaN                  NaN              NaN
# 6   NaN                NaN                  NaN              NaN
# 7   NaN                NaN                  NaN              NaN
# 8   NaN                NaN                  NaN              NaN
# 9   NaN                NaN                  NaN              NaN
#
#   block_offensive carry_end_location clearance_aerial_won clearance_body_part
# 0             NaN                NaN                  NaN                 NaN  \
# 1             NaN                NaN                  NaN                 NaN
# 2             NaN                NaN                  NaN                 NaN
# 3             NaN                NaN                  NaN                 NaN
# 4             NaN                NaN                  NaN                 NaN
# 5             NaN                NaN                  NaN                 NaN
# 6             NaN                NaN                  NaN                 NaN
# 7             NaN                NaN                  NaN                 NaN
# 8             NaN                NaN                  NaN                 NaN
# 9             NaN                NaN                  NaN                 NaN
#
#   clearance_head clearance_left_foot  ... substitution_outcome
# 0            NaN                 NaN  ...                  NaN  \
# 1            NaN                 NaN  ...                  NaN
# 2            NaN                 NaN  ...                  NaN
# 3            NaN                 NaN  ...                  NaN
# 4            NaN                 NaN  ...                  NaN
# 5            NaN                 NaN  ...                  NaN
# 6            NaN                 NaN  ...                  NaN
# 7            NaN                 NaN  ...                  NaN
# 8            NaN                 NaN  ...                  NaN
# 9            NaN                 NaN  ...                  NaN
#
#   substitution_outcome_id substitution_replacement
# 0                     NaN                      NaN  \
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
# 5                     NaN                      NaN
# 6                     NaN                      NaN
# 7                     NaN                      NaN
# 8                     NaN                      NaN
# 9                     NaN                      NaN
#
#   substitution_replacement_id
# 0                         NaN  \
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
#
#                                              tactics     team  team_id
# 0  {'formation': 433, 'lineup': [{'player': {'id'...    Italy      914  \
# 1  {'formation': 4231, 'lineup': [{'player': {'id...  Albania      906
# 2                                                NaN  Albania      906
# 3                                                NaN    Italy      914
# 4                                                NaN  Albania      906
# 5                                                NaN    Italy      914
# 6                                                NaN  Albania      906
# 7                                                NaN  Albania      906
# 8                                                NaN  Albania      906
# 9                                                NaN    Italy      914
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN
# 5  00:00:00.000   Half Start            NaN
# 6  00:00:00.863         Pass            NaN
# 7  00:00:02.579         Pass            NaN
# 8  00:00:04.984         Pass            NaN
# 9  00:00:20.848         Pass            NaN
#
# [10 rows x 92 columns]

# %%
events.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot', 'clearance_right_foot', 'counterpress',
#        'dribble_nutmeg', 'dribble_outcome', 'duel_outcome', 'duel_type',
#        'duration', 'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_shot_saved_to_post',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'injury_stoppage_in_chain', 'interception_outcome', 'location',
#        'match_id', 'minute', 'miscontrol_aerial_won', 'off_camera', 'out',
#        'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
#        'pass_body_part', 'pass_cross', 'pass_cut_back', 'pass_deflected',
#        'pass_end_location', 'pass_goal_assist', 'pass_height',
#        'pass_inswinging', 'pass_length', 'pass_outcome', 'pass_outswinging',
#        'pass_recipient', 'pass_recipient_id', 'pass_shot_assist',
#        'pass_switch', 'pass_technique', 'pass_through_ball', 'pass_type',
#        'period', 'play_pattern', 'player', 'player_id', 'position',
#        'possession', 'possession_team', 'possession_team_id', 'related_events',
#        'second', 'shot_aerial_won', 'shot_body_part', 'shot_end_location',
#        'shot_first_time', 'shot_freeze_frame', 'shot_key_pass_id',
#        'shot_one_on_one', 'shot_outcome', 'shot_saved_to_post',
#        'shot_statsbomb_xg', 'shot_technique', 'shot_type',
#        'substitution_outcome', 'substitution_outcome_id',
#        'substitution_replacement', 'substitution_replacement_id', 'tactics',
#        'team', 'team_id', 'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %% [markdown]
# ## Step 6.2: General Match Analysis

# %% [markdown]
# Here we extract the starting lineup information directly from the event data retrieved for the match. In the StatsBomb dataset, the event type "Starting XI" contains tactical lineup information for each team before kickoff. By filtering events[events['type'] == 'Starting XI'], it isolates the rows where the team’s starting formation is recorded. The tactics['lineup'] field within each "Starting XI" row holds a list of dictionaries, each representing a player in the lineup. The code then loops through this list, extracting and printing each player’s jersey number and full name under the corresponding team name.

# %%
# Filter for 'Starting XI' rows
starting_xi_rows = events[events['type'] == 'Starting XI']

for i, row in starting_xi_rows.iterrows():
    print("TEAM:", row['team'])
    lineup = row['tactics']['lineup']
    scheme = row['tactics']['formation']
    print("Scheme:", scheme)
    
    for pl in lineup:

        # Extract player name
        pinfo = pl['player']
        player_name = pinfo.get('name', 'Unknown')

        # Extract jersey number
        jersey = pl.get('jersey_number', '??')

        # Extract player position
        position = pl['position']
        pos = position.get('name', 'Unknown')
        print(f"    [{pos}] {jersey} - {player_name}")
    
    print(40*"-")
# Out:
# TEAM: Italy
# Scheme: 433
#     [Goalkeeper] 1 - Gianluigi Donnarumma
#     [Right Back] 2 - Giovanni Di Lorenzo
#     [Right Center Back] 23 - Alessandro Bastoni
#     [Left Center Back] 5 - Riccardo Calafiori
#     [Left Back] 3 - Federico Dimarco
#     [Center Defensive Midfield] 8 - Jorge Luiz Frello Filho
#     [Right Center Midfield] 7 - Davide Frattesi
#     [Left Center Midfield] 18 - Nicolò Barella
#     [Right Wing] 14 - Federico Chiesa
#     [Left Wing] 10 - Lorenzo Pellegrini
#     [Center Forward] 9 - Gianluca Scamacca
# ----------------------------------------
# TEAM: Albania
# Scheme: 4231
#     [Goalkeeper] 23 - Thomas Strakosha
#     [Right Back] 4 - Elseid Hysaj
#     [Right Center Back] 5 - Arlind Afrim Ajeti
#     [Left Center Back] 6 - Berat Djimsiti
#     [Left Back] 3 - Mario Mitaj
#     [Right Defensive Midfield] 20 - Ylber Ramadani
#     [Left Defensive Midfield] 21 - Kristjan Asllani
#     [Right Wing] 9 - Jasir Asani
#     [Center Attacking Midfield] 10 - Nedim Bajrami
#     [Left Wing] 15 - Taulant Sulejmanov
#     [Center Forward] 11 - Armando Broja
# ----------------------------------------

# %% [markdown]
# ### Step 6.2.1: Passes Analysis

# %% [markdown]
# Here we analyze the passing events in the match, focusing on pass completion rates for both teams. As above, we first filters the events data to isolate only "Pass" events. Then, we classify passes as completed or incomplete based on whether pass_outcome is NaN (a missing outcome indicates success). The script calculates and prints total passes, the number of completed and incomplete passes, and the overall pass precision (completion percentage). It further breaks these stats down by team, showing total passes, completed passes, and pass completion percentage for each tean.

# %%
# Filter for 'Pass' events
passes = events[events['type'] == 'Pass'].copy()

# If 'pass_outcome' is NaN => pass was successful
completed_passes = passes[passes['pass_outcome'].isna()]
incomplete_passes = passes[~passes['pass_outcome'].isna()]

print("Total passes:", passes.shape[0])
print("  Completed:", completed_passes.shape[0])
print("  Incomplete:", incomplete_passes.shape[0])
print("  Precision:", round(completed_passes.shape[0] / passes.shape[0], 2))

# Passes by team
team_passes = passes.groupby('team').size()
team_completed = completed_passes.groupby('team').size()

print("\nPasses by team (total):\n", team_passes)
print("\nCompleted by team:\n", team_completed)

# Percentage of completed passes
team_pass_pct = (team_completed / team_passes)
print("\nCompletion % by team:\n", round(team_pass_pct,2))
# Out:
# Total passes: 1261
#   Completed: 1124
#   Incomplete: 137
#   Precision: 0.89
#
# Passes by team (total):
#  team
# Albania    406
# Italy      855
# dtype: int64
#
# Completed by team:
#  team
# Albania    340
# Italy      784
# dtype: int64
#
# Completion % by team:
#  team
# Albania    0.84
# Italy      0.92
# dtype: float64

# %% [markdown]
# ### Step 6.2.2: Shots Analysis

# %% [markdown]
# Now, lwt's analyze the shot events from the match. First of all, we filter the events to keep only rows where the event type is "Shot", then counts how many shots each team took. Then, we calculate the total xG per team by summing the shot_statsbomb_xg values, which estimate the probability of each shot resulting in a goal based on historical data. Lastly, it identifies the top five players by shot count, providing insight into which individuals were most involved in taking attempts at goal. This breakdown helps assess team attacking efficiency and individual shooting contribution.

# %%
# Filter for 'Shot' events & summarize xG, who took the shots, etc.
shots = events[events['type'] == 'Shot'].copy()

# Shots per team
team_shot_count = shots['team'].value_counts()
print(f"Shots per team:\n {team_shot_count}")

# xG per team
shots['xg'] = shots['shot_statsbomb_xg']
team_xg = shots.groupby('team')['xg'].sum()
print(f"\nTotal xG by team:\n {team_xg}")

# Show top 5 shooters by number of shots
player_shots = shots['player'].value_counts().head(5)
print(f"\nTop 5 shooters (by shot count):\n {player_shots}")
# Out:
# Shots per team:
#  team
# Italy      17
# Albania     8
# Name: count, dtype: int64
#
# Total xG by team:
#  team
# Albania    0.354597
# Italy      1.449797
# Name: xg, dtype: float64
#
# Top 5 shooters (by shot count):
#  player
# Lorenzo Pellegrini    3
# Federico Chiesa       3
# Gianluca Scamacca     3
# Jasir Asani           2
# Federico Dimarco      2
# Name: count, dtype: int64

# %% [markdown]
# Let's now visually represents the shot locations for both teams on a soccer pitch, distinguishing between home and away teams. As always, let's first identifies the home and away teams from the event data and filters for "Shot" events. Then splits the shots into two groups based on the team, printing the total number of shots each team took. The script extracts the (x, y) coordinates of each shot and plots them on a pitch using draw_pitch(ax=ax).

# %%
# Identify home & away teams from the event data
home_team, away_team = events['team'].unique()

# Filter for Shot events
shots = events[events['type'] == 'Shot'].copy()

# Split the DataFrame by team
home_shots = shots[shots['team'] == home_team]
away_shots = shots[shots['team'] == away_team]

# Print how many shots each team had
print(f"{home_team} shots:", len(home_shots))
print(f"{away_team} shots:", len(away_shots))

# Extract x,y for home shots
home_shot_x = home_shots['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
home_shot_y = home_shots['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Extract x,y for away shots
away_shot_x = away_shots['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
away_shot_y = away_shots['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Create figure & draw the pitch
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)

# Scatter home shots in blue
ax.scatter(
    home_shot_x, home_shot_y, 
    c='blue', edgecolors='black', alpha=0.7,
    label=home_team, zorder=3                       # The zorder=3 ensures the dots appear above the pitch lines
)

# Scatter away shots in red
ax.scatter(
    away_shot_x, away_shot_y, 
    c='red', edgecolors='black', alpha=0.7,
    label=away_team, zorder=3
)

# Add a title, legend, and show
ax.set_title("Shot Locations on the Pitch", color="black", fontsize=14, fontweight='bold')
ax.legend(facecolor="white", edgecolor="black")
plt.show()
# Out:
# Italy shots: 17
# Albania shots: 8

# %% [markdown]
# Here we visualizes shot locations on a soccer pitch, with each shot’s size scaled by expected goals (xG) and color-coded based on whether it resulted in a goal. Expected goals (xG) is a statistical model that estimates the probability of a shot resulting in a goal, based on various contextual factors like shot distance, angle, body part used, and defensive pressure. An xG value closer to 1.0 means a high probability of scoring (e.g., a tap-in from close range), while a low xG (e.g., 0.05) indicates a difficult attempt (e.g., a long-range shot under pressure).
#
# The size of each marker is scaled, so high-xG chances appear larger on the pitch, while small circles represent low-probability shots. The color of each shot is set to gold for goals and dark gray for missed attempts.

# %%
# Filter for Shot events
shots = events[events['type'] == 'Shot'].copy()

# Extract xG, location, outcome
shots['xg'] = shots['shot_statsbomb_xg']  # numeric float
shots['is_goal'] = shots['shot_outcome'] == "Goal"

# x,y for plotting
shots['x'] = shots['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
shots['y'] = shots['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Scale circle size by xG, e.g. multiply by 1000 for visibility
shots['marker_size'] = shots['xg'] * 1000

# Color-code: gold if goal, darkgray if not
shots['color'] = shots['is_goal'].map({True: 'gold', False: 'darkgray'})

# Create a figure and draw the pitch
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)
ax.set_title("Shots scaled by Expected Goals xG (Gold = Goal)", color="Black", fontsize=14, fontweight='bold')

# Scatter: each shot is a circle whose area ~ xG
ax.scatter(
    shots['x'], 
    shots['y'],
    s=shots['marker_size'],      # circle area (size)
    c=shots['color'],            # color
    alpha=0.7,
    edgecolors='black',
    linewidths=1.0,
    zorder=3
)

plt.show()

# %% [markdown]
# ## Step 6.3: Player Analysis

# %% [markdown]
# This cell provides an overview of player involvement by counting different event types per player.

# %%
# Count the number of events per player
player_actions = events['player'].value_counts()

print("Total actions per player (all event types):")
print(player_actions.head(10))  # Show top 10 players by event count
# Out:
# Total actions per player (all event types):
# player
# Giovanni Di Lorenzo        393
# Jorge Luiz Frello Filho    392
# Nicolò Barella             342
# Alessandro Bastoni         336
# Riccardo Calafiori         324
# Kristjan Asllani           182
# Federico Dimarco           179
# Berat Djimsiti             172
# Federico Chiesa            154
# Arlind Afrim Ajeti         149
# Name: count, dtype: int64

# %% [markdown]
# ### Step 6.3.1: Top Performers

# %% [markdown]
# This cell identifies the top three players in four categories: passes, shots, tackles, and dribbles. It first filters the event dataset for each action type (Pass, Shot, Duel, Dribble), counts how often each player performed that action, and retrieves their team name.
# The function get_team(player_name) extracts the player’s team from the event data. Each ranking is stored as a DataFrame.

# %%
# Function to retrieve a player's team
def get_team(player_name):
    team = events[events['player'] == player_name]['team'].unique()
    return team[0] if len(team) > 0 else "Unknown"

# Extract top performers for each action type
top_passers = events[events['type'] == 'Pass']['player'].value_counts().head(3)
top_shooters = events[events['type'] == 'Shot']['player'].value_counts().head(3)
top_tacklers = events[events['type'] == 'Duel']['player'].value_counts().head(3)
top_dribblers = events[events['type'] == 'Dribble']['player'].value_counts().head(3)

# Convert to DataFrame and add team information
def create_leaderboard(series, action_name):
    df = pd.DataFrame({'Player': series.index, action_name: series.values})
    df['Team'] = df['Player'].apply(get_team)
    return df

# Generate tables for each category
top_passers_df = create_leaderboard(top_passers, 'Passes')
top_shooters_df = create_leaderboard(top_shooters, 'Shots')
top_tacklers_df = create_leaderboard(top_tacklers, 'Duels')
top_dribblers_df = create_leaderboard(top_dribblers, 'Dribbles')

# Display the top performers for each category
print("Top Passers:")
display(top_passers_df)

print("\nTop Shooters:")
display(top_shooters_df)

print("\nTop Tacklers:")
display(top_tacklers_df)

print("\nTop Dribblers:")
display(top_dribblers_df)
# Out:
# Top Passers:
#                     Player  Passes   Team
# 0  Jorge Luiz Frello Filho     131  Italy
# 1      Giovanni Di Lorenzo     131  Italy
# 2       Alessandro Bastoni     115  Italy
# Top Shooters:
#                Player  Shots   Team
# 0  Lorenzo Pellegrini      3  Italy
# 1     Federico Chiesa      3  Italy
# 2   Gianluca Scamacca      3  Italy
# Top Tacklers:
#                 Player  Duels     Team
# 0        Armando Broja      4  Albania
# 1  Giovanni Di Lorenzo      3    Italy
# 2        Mateo Retegui      3    Italy
# Top Dribblers:
#             Player  Dribbles     Team
# 0  Federico Chiesa         6    Italy
# 1    Armando Broja         1  Albania
# 2   Nicolò Barella         1    Italy

# %% [markdown]
# ### Step 6.3.2: Passes Analysis

# %% [markdown]
# Here we analyze the successful passes in the match, focusing on pass direction (forward, sideways, or backward) by filtering only completed passes, calculating the pass angle, and categorizing each pass based on its trajectory. Finally, we counts how many passes each player made in each direction and presents the results in a DataFrame.

# %%
# Filter successful passes
successful_passes = events[(events['type'] == 'Pass') & (events['pass_outcome'].isna())].copy()

# Calculate pass direction (forward, backward, sideways)
# Uses np.arctan2(y_change, x_change) to calculate the direction of the pass based on its start and end location using the radiants as the angle unit
# if the angle is between -pi/4 and pi/4, the pass is forward
# if the angle is between pi/4 and 3pi/4 or -3pi/4 and -pi/4, the pass is sideways
# otherwise, the pass is backward
successful_passes['pass_angle'] = np.arctan2(
    successful_passes['pass_end_location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan) - 
    successful_passes['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan),
    successful_passes['pass_end_location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan) - 
    successful_passes['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
)

# Define direction categories
def categorize_pass(angle):
    if -np.pi/4 <= angle <= np.pi/4:
        return "Forward"
    elif np.pi/4 < angle <= 3*np.pi/4 or -3*np.pi/4 <= angle < -np.pi/4:
        return "Sideways"
    else:
        return "Backward"

successful_passes['pass_direction'] = successful_passes['pass_angle'].apply(categorize_pass)

# Count passes by direction for each player
pass_directions = successful_passes.groupby(['team', 'player', 'pass_direction']).size().unstack(fill_value=0).reset_index()

# Display results
print("Passes by direction for each player:")
display(
    pass_directions.sort_values(by='Forward', ascending=False)
)
# Out:
# Passes by direction for each player:
# pass_direction     team                      player  Backward  Forward
# 23                Italy         Giovanni Di Lorenzo        15       34  \
# 15                Italy          Alessandro Bastoni        13       23
# 29                Italy          Riccardo Calafiori         4       23
# 24                Italy     Jorge Luiz Frello Filho        21       21
# 28                Italy              Nicolò Barella        17       18
# 8               Albania                 Mario Mitaj        12       17
# 4               Albania                Elseid Hysaj        10       10
# 22                Italy        Gianluigi Donnarumma         0        9
# 1               Albania          Arlind Afrim Ajeti         1        8
# 14              Albania              Ylber Ramadani         5        8
# 7               Albania            Kristjan Asllani         6        7
# 3               Albania              Berat Djimsiti         2        7
# 20                Italy            Federico Dimarco        28        6
# 13              Albania            Thomas Strakosha         0        5
# 2               Albania               Armando Broja         1        4
# 25                Italy          Lorenzo Pellegrini        13        3
# 17                Italy             Bryan Cristante         7        3
# 18                Italy             Davide Frattesi        11        3
# 12              Albania          Taulant Sulejmanov         3        2
# 6               Albania                 Jasir Asani         6        2
# 26                Italy              Matteo Darmian         4        1
# 9               Albania               Nedim Bajrami         7        1
# 19                Italy             Federico Chiesa         9        1
# 21                Italy           Gianluca Scamacca         3        1
# 27                Italy  Michael Ijemuan Folorunsho         0        0
# 16                Italy             Andrea Cambiaso         6        0
# 11              Albania                   Rey Manaj         1        0
# 10              Albania                  Qazim Laçi         0        0
# 5               Albania                 Ernest Muçi         0        0
# 0               Albania                 Arbër Hoxha         2        0
#
# pass_direction  Sideways
# 23                    74
# 15                    75
# 29                    74
# 24                    78
# 28                    70
# 8                     15
# 4                     11
# 22                     9
# 1                     37
# 14                    26
# 7                     40
# 3                     41
# 20                    19
# 13                    12
# 2                      3
# 25                    24
# 17                    17
# 18                    15
# 12                     4
# 6                      0
# 26                     3
# 9                     15
# 19                    17
# 21                     8
# 27                     1
# 16                     3
# 11                     0
# 10                     6
# 5                      3
# 0                      0

# %% [markdown]
# ### Step 6.3.3: Dribble and Carry Analysis

# %% [markdown]
# This cell evaluates dribbling performance, identifying which players attempt the most dribbles and how successful they are. It first filters all dribble events, then separates them into successful and unsuccessful attempts based on the "dribble_outcome" column. The code then computes dribble attempts, successful dribbles, and success rate (%) for each player, highlighting the top dribblers.

# %%
# Filter dribble events
dribbles = events[events['type'] == 'Dribble'].copy()

# Separate successful and unsuccessful dribbles
successful_dribbles = dribbles[dribbles['dribble_outcome'] == 'Complete']
unsuccessful_dribbles = dribbles[dribbles['dribble_outcome'] == 'Incomplete']

# Count dribble attempts & successful dribbles per player
dribble_stats = dribbles.groupby(['team', 'player']).size().to_frame('Attempts')
dribble_stats['Successful'] = successful_dribbles.groupby(['team', 'player']).size()
dribble_stats['Successful'] = dribble_stats['Successful'].fillna(0).astype(int)  # Fill NaN for players without successful dribbles
dribble_stats['Success %'] = (dribble_stats['Successful'] / dribble_stats['Attempts']) * 100

# Sort by most successful dribbles and display top 10 players
dribble_stats = dribble_stats.sort_values(by='Success %', ascending=False)
print("Dribble stats for each player:")
display(dribble_stats)
# Out:
# Dribble stats for each player:
#                          Attempts  Successful  Success %
# team    player
# Italy   Federico Chiesa         6           5  83.333333
# Albania Armando Broja           1           0   0.000000
# Italy   Davide Frattesi         1           0   0.000000
#         Matteo Darmian          1           0   0.000000
#         Nicolò Barella          1           0   0.000000

# %% [markdown]
# Now let's analyze the progressive runs, by identifying players who carry the ball forward the most during a match. We extract “Carry” events from the dataset, calculates the distance covered in each run using the euclidean distance, and highlights the top ball carriers by total progressive distance.

# %%
# Filter Carry (Ball Progression) events
carries = events[events['type'] == 'Carry'].copy()

# Compute Carry Distance
carries['carry_distance'] = carries.apply(lambda row: 
    np.sqrt((row['carry_end_location'][0] - row['location'][0])**2 + 
            (row['carry_end_location'][1] - row['location'][1])**2)
    if isinstance(row['carry_end_location'], list) and isinstance(row['location'], list) else np.nan, axis=1)

# Sum total carry distance per player
carry_stats = carries.groupby(['team', 'player'])['carry_distance'].sum().reset_index()
carry_stats.columns = ['Team', 'Player', 'Total Carry Distance (m)']

# Sort by the most progressive players
top_carriers = round(carry_stats.sort_values('Total Carry Distance (m)', ascending=False),2)

# Display results
print("Total Carry Distance for each player:")
display(top_carriers.head(10))
# Out:
# Total Carry Distance for each player:
#        Team                   Player  Total Carry Distance (m)
# 29    Italy       Riccardo Calafiori                    524.81
# 15    Italy       Alessandro Bastoni                    523.11
# 28    Italy           Nicolò Barella                    480.25
# 23    Italy      Giovanni Di Lorenzo                    312.14
# 24    Italy  Jorge Luiz Frello Filho                    283.79
# 7   Albania         Kristjan Asllani                    273.43
# 25    Italy       Lorenzo Pellegrini                    260.60
# 19    Italy          Federico Chiesa                    227.07
# 14  Albania           Ylber Ramadani                    199.88
# 18    Italy          Davide Frattesi                    156.33

# %% [markdown]
# ### Step 6.3.4: Defensive Analysis

# %% [markdown]
# this visualization isolates the single most active defensive player and highlights where they perform tackles, interceptions, and blocks on the pitch by selecting this events in the events object

# %%
import matplotlib.pyplot as plt

# Filter Defensive Events
defensive_actions = events[events['type'].isin(["Interception", "Duel", "Block"])].copy()

# Identify the Most Active Defensive Player
top_defender = defensive_actions['player'].value_counts().idxmax()
player_defensive_actions = defensive_actions[defensive_actions['player'] == top_defender]

# Create the pitch
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)
ax.set_title(f"Defensive Actions by {top_defender}", color="black", fontsize=14, fontweight='bold')

# Plot Different Defensive Actions with Unique Markers
for action, marker, color in zip(["Interception", "Duel", "Block"], ["s", "o", "D"], ["red", "blue", "yellow"]):
    action_events = player_defensive_actions[player_defensive_actions['type'] == action]
    x = action_events['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
    y = action_events['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)
    
    ax.scatter(x, y, c=color, label=action, marker=marker, edgecolors="black", zorder = 3, s=100)

# Add a legend and show the plot
ax.legend(facecolor="white", edgecolor="black", fontsize=12, loc="upper right")
plt.show()

# %% [markdown]
# ## Step 6.4: Further Analysis

# %% [markdown]
# ### Step 6.4.1: Team Defensive Pressing Intensity Heatmap

# %% [markdown]
# This visualization will show where a team applies the most defensive pressure, based on:
# 	•	Duel events (tackles & challenges).
# 	•	Interceptions (reading passing lanes).
# 	•	Ball recoveries (winning possession).
# This will directly align with real-time tactical insights, showing where a team is pressing high, staying compact, or struggling defensively

# %%
# Filter Defensive Actions for a Specific Team
team_defensive_actions = events[(events['team'] == home_team) & 
                                (events['type'].isin(["Interception", "Duel", "Ball Recovery"]))]

# Extract x,y locations
x_def = team_defensive_actions['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
y_def = team_defensive_actions['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Create Pitch & Heatmap
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)

# Heatmap overlay
sns.kdeplot(x=x_def, y=y_def, cmap="Reds", fill=True, alpha=0.6, ax=ax)

ax.set_title(f"{home_team} Defensive Pressing Intensity Heatmap", color="black", fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ### Step 6.4.2: Shot Intensity Heatmap (Danger Zones)

# %% [markdown]
# The Shot Intensity Heatmap is a visualization that helps teams to identify shooting patterns & weaknesses. It is used in AI models to predict goal-scoring probabilities.

# %%
# Filter Shot Events
shots = events[events['type'] == 'Shot']

# Extract shot locations
x_shots = shots['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
y_shots = shots['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Create Pitch & Heatmap
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)

# Overlay the heatmap for shot intensity
sns.kdeplot(x=x_shots, y=y_shots, cmap="Oranges", fill=True, alpha=0.6, ax=ax)

ax.set_title("Shot Intensity Heatmap (Danger Zones)", color="black", fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ### Step 6.4.3: Player Pressing Intensity Heatmap (Defensive Action)

# %% [markdown]
# This heatmap visualizes where a randomly selected player applies defensive pressure during the match. It highlights locations of interceptions, duels, and ball recoveries, helping identify whether the player is involved in high pressing, midfield ball-winning, or defensive blocks.

# %%
# Select a Random Player from the Match
players_in_match = events['player'].dropna().unique()
random_player = random.choice(players_in_match)

# Filter Defensive Actions for the Player
player_defensive_actions = events[(events['player'] == random_player) & 
                                  (events['type'].isin(["Interception", "Duel", "Ball Recovery"]))]

# Extract x, y locations
x_def = player_defensive_actions['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
y_def = player_defensive_actions['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Create Pitch & Heatmap for Pressing Intensity
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)
sns.kdeplot(x=x_def, y=y_def, cmap="Reds", fill=True, alpha=0.6, ax=ax)
ax.set_title(f"Pressing Intensity Heatmap - {random_player}", color="black", fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ### Step 6.4.4: Player Movement Heatmap

# %% [markdown]
# This heatmap illustrates the movement and positioning of a randomly selected player throughout the match. It shows where the player is most active, helping to understand their positional tendencies, involvement in buildup play, and tactical role.

# %%
# Select a Random Player from the Match
players_in_match = events['player'].dropna().unique()
random_player = random.choice(players_in_match)

# Filter all actions by the Player
player_actions = events[events['player'] == random_player]

# Extract x, y locations
x_movement = player_actions['location'].apply(lambda loc: loc[0] if isinstance(loc, list) else np.nan)
y_movement = player_actions['location'].apply(lambda loc: loc[1] if isinstance(loc, list) else np.nan)

# Create Pitch & Heatmap for Player Movement
fig, ax = plt.subplots(figsize=(12,8))
draw_pitch(ax=ax)
sns.kdeplot(x=x_movement, y=y_movement, cmap="Purples", fill=True, alpha=0.6, ax=ax)
ax.set_title(f"Player Movement Heatmap - {random_player}", color="black", fontsize=14, fontweight='bold')
plt.show()
